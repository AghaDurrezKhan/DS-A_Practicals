# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "/content/All Quiet on the Western Front.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Amidst the muddied trenches and the incessant rumble of artillery fire, a hushed tension gripped the soldiers. They had heard whispers about a new, monstrous weapon that the enemy was rumored to be deploying. It wasn't long before those rumors were confirmed.
# A low, thunderous growl, like some primeval beast, reverberated through the battlefield. Paul Baumer and his comrades huddled in their trench, their eyes wide with both awe and terror. The ground beneath them quivered as colossal machines of war loomed over the horizon.
# In the dim light of dawn, the behemoths materialized – the tanks. Massive, ironclad monsters on caterpillar tracks, they seemed invincible, impervious to the bullets and shells that had, until now, been the bane of infantrymen. The soldiers watched in a mixture of horror and fascination as the enemy tanks bore down upon them.
# The tanks moved with an eerie, mechanical grace, crushing barbed wire and fortifications beneath their colossal weight. Their turrets swiveled ominously, and from their gun barrels, fiery death erupted. Explosions blossomed all around, the deafening roar of the tanks' cannons blending with the continuous barrage of artillery.
# Paul felt his heart pounding in his chest, and his breaths came in ragged gasps. The battlefield had turned into a surreal nightmare. Men around him shouted, cursed, and scrambled for cover, but there was little shelter to be found.
# As the tanks advanced, their monstrous presence became more surreal. The world of mud and blood was now ruled by these mechanical beasts. It was a terrifying embodiment of the relentless, impersonal nature of modern warfare. Soldiers fired futilely at the armored giants, their bullets bouncing harmlessly off the tank's thick armor.
# With each passing moment, hope dwindled. It was a moment of reckoning, a brutal reminder of the overwhelming force of industrialized warfare. Paul Baumer and his comrades faced not only an enemy across the battlefield but also the inexorable advance of technology.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://www.britannica.com/")
print(r.text)
# Out:
# <!doctype html>
#
# <html data-ytrk-page="HOME" lang="en" class="home-desktop ui-unknown0 ui-unknown">
#
# <head prefix="og: https://ogp.me/ns# fb: https://ogp.me/ns/fb#">
#
#     <meta charset="utf-8">
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
#     <meta property="fb:pages" content="74442380906" />
#
# 	<link rel="dns-prefetch" href="https://cdn.britannica.com/mendel-resources/3-105">
# 	<link rel="preconnect" href="https://cdn.britannica.com/mendel-resources/3-105">
#
#     <link rel="preload" as="script" href="https://www.googletagservices.com/tag/js/gpt.js" />
#
#     <link rel="icon" href="/favicon.png" />
#
#     <meta name="description" content="Explore the fact-checked online encyclopedia from Encyclopaedia Britannica with hundreds of thousands of objective articles, biographies, videos, and images from experts." />
# 		<meta name="keywords" content="britannica, reference, online, encyclopedia, encyclopaedia, store, dictionary, thesaurus" />
#
#     <link rel="canonical" href="https://www.britannica.com/" />
#     <title>Encyclopedia Britannica | Britannica</title>
# 		<script type="text/javascript" data-type="Init Mendel">
#
#     window.$UI = {};
#
#     window.Constants = {"LICENSE_URL": "/bps/license","DEFAULT_TEST_VERSION": "A","DEFAULT_STATE": "XX","QUIZ_URL": "/quiz","SPOTLIGHT_BROWSE_URL": "/stories/spotlight","CONTENT_TYPE_TEXT": "text/plain;charset=UTF-8","TOPIC_FACTS_DATA_URL": "/facts","QUIZ_BROWSE_IMAGE_QUIZZES": "images","TOPIC_MEDIA_PATH": "/images-videos","USER_PROFILE_URL": "/user","DEBUG_URL": "/debug","ONE_GOOD_FACT_URL": "/one-good-fact","ERROR_404_URL": "/error404","INSTANT_ARTICLES_URL": "/instant-articles","TOPIC_PAGE_CONTENT_AJAX_URL": "/topic-content/page","INFINITE_SCROLL_PREFIX_URL": "/scroll","TOPIC_TOP_QUESTION_BROWSE_URL": "/questions","CC_USD": "USD","domain": "britannica.com","SURVEY_URL": "/survey","PROCON_PAGE_URL": "/procon","CATEGORY_BROWSE_URL": "/browse","STORY_BROWSE_URL": "/stories","COUNTRY_US": "US","OPEN_MEDIA_OVERLAY_PARAMETER": "/media","NEWSLETTER_SUBSCRIPTION_URL": "/newsletter-subscription","INSIGHTS_LANDING_PAGE_URL_2": "/factsmatter","INSIGHTS_LANDING_PAGE_URL_1": "/insights","KUSTOM_MONEY_APPLICATION_ID": "2","MAINTENANCE_ERROR_URL": "https://maintenance.eb.com","IMARS_EDITOR_ID": "12365882","PROFILE_EB_EDITOR_URL": "/editor","WEB_INF_RESOURCES_PATH": "WEB-INF/resources","TOPIC_ADDITIONAL_INFO_PATH": "/additional-info","SUDOKU_GAME_URL": "/games/sudoku","CC_INR": "INR","ARTICLE_PRINT_URL": "/print/article","FIRST_EDITION_URL": "/subscriber/firstedition","WW1_PORTAL_URL": "/discover/World-War-I","MENDEL_COOKIE": "__mendel","DEMYSTIFIED_BROWSE_URL": "/stories/demystified","LIST_BROWSE_URL": "/list/browse","PROFILE_EXPERT_URL": "/contributor","ASSEMBLY_IMAGE_URL": "/image/assembly","DAY_IN_HISTORY_URL": "/on-this-day","DEFAULT_CURRENCY": "USD","CONTENT_TYPE_XML": "text/xml;charset=UTF-8","AJAX_PREFIX_URL": "/ajax","TOPIC_BROWSE_URL": "/topic-browse","MARKETING_CONTENT": "/marketing-content","ENV_RUNTIME": "runtime","GALLERY_URL": "/gallery","REDIRECTED_MONEY_TOPIC_URL_PREFIX": "money/topic","CONTENT_TYPE_HTML": "text/html;charset=UTF-8","ENV_LOCAL": "override","MEDIA_OVERLAY_URL": "/media-overlay","NEWSLETTER_PAGE_URL": "/newsletters","MONEY_SUPERCATEGORY_ID": "7","ENV_DEV": "development","MEDIA_URL": "/media","TOPIC_TOP_QUESTION_URL": "/question","PORTAL_FINANCE_URL_PREFIX": "/money","PODCASTS_URL": "/podcasts","STAND_ALONE_VIDEO_URL": "/video","MORE_ON_THIS_DAY_URL": "/more-on-this-day","TOPIC_QUOTES_URL": "/quotes","SEARCH_PAGE_URL": "/search","KUSTOM_MENDEL_APPLICATION_ID": "1","TOPIC_CONTENT_AJAX_URL": "/topic-content/topic","ENV_BRANCH": "branch","ERROR_URL": "/error","MAIN_VERSION": "mainVersion","DEFAULT_S3_REGION": "US_EAST_1","TOPIC_COLLECTION_URL": "/summary","LOGINBOX_URL": "/auth/loginbox","ONE_GOOD_FACT_BROWSE_URL": "/one-good-fact/all-good-facts","QUIZ_BROWSE_URL": "/quiz/browse","BIO_BROWSE_URL": "/browse/biographies","LIST_URL": "/list","portalRootUrl": "{1=/money}","ALPHA_BROWSE_URL": "/sitemap","CONTENT_TYPE_JSON": "application/json","DICTIONARY_URL": "/dictionary","COBRAND_IMAGE_URL": "/image/cobrand","PROCON_BROWSE_URL": "/procon/browse","QUIZ_BROWSE_VOCAB_QUIZZES": "vocabulary-quizzes","SUBMISSION_URL": "/submission","EB_LOG_OUT": "/auth2/logout","ENV_PRODUCTION": "production","TOPIC_AJAX_URL": "/ajax/topic","TOPIC_SUMMARY_BROWSE_URL": "/summaries","WTFACT_BROWSE_URL": "/stories/wtfact","VIDEO_CHANNEL_URL": "/videos","GALLERY_BROWSE_URL": "/gallery/browse","CACHE_URL": "/cache","COMPANION_BROWSE_URL": "/stories/companion","MEDIA_FOLDER": "/eb-media","SHOW_ALL_CONTRIBUTORS": "/additional-info#contributors","BRITANNICA_EDITORS_ID": "4419","EXPLORE_BROWSE": "/explore","ENV_CACHE_DISABLED": "mendelCache","STORY_URL": "/story","DEFAULT_COUNTRY": "US","NAVBAR_URL": "/ajax/navbar","EB_LOGIN_URL": "/auth/eb-login","NEW_ARTICLES_URL": "/new-articles","topicClasses": "[topic, animal, art, biography, event, place, plant, science, sports, technology]",};
#     window.CDN = "https://cdn.britannica.com";
#     window.CAM_LOGIN_URL = "https://cam.britannica.com";
#     window.CAM_SIGN_UP_URL = "https://cam.britannica.com/registration"
#
#     window.Mendel = {
#      	"config" : {
#       		"domain": "britannica.com",
# 			"page": "Home",
# 			"videoPlayerId": "UyMCoK2v",
# 			"sharedUrl": "https://www.britannica.com/",
# 			"amuselabsUrl": "https://cdn3.amuselabs.com",
# 	    	"resourcesPrefixUrl": "https://cdn.britannica.com/mendel-resources/3-105/[url]?v=3.105.08",
# 			"userInfo": { "type": "ANONYMOUS"
# 			             ,"currency": "USD"
# 			             ,"country": "US"
# 					     ,"state": "SC"
# 			             ,"bcomId": "2894323506733219755"
# 				         ,"hasAds": true
# 					     ,"testVersion": "D"
# 						 ,"adsTestVersion": "D"
# 				         ,"privacyInfo": {"consentLocation":false,"gdpr":false,"ccpa":false,"needConsent":false}
# 						 ,"consumerId": ""
# 						 ,"instId": ""
# 						 ,"consumerUserName": ""
# 						 ,"instUserName": ""
# 						 ,"cognito": null
# 			},
# 			"tvs":{ "r":[2,2,46,50], "a": [2,2,46,50]},
# 			"isLoggedInAsUser": false,
# 			"analytics": {  "gaId": "UA-6636134-11" },
# 			"isPhone": false,
# 			"isDesktop": true,
# 			"logoutUrl": "/auth2/logout",
# 			"selfServiceUrl": "https://myaccount.britannica.com",
# 			"cdnUrl": "https://cdn.britannica.com",
# 	        "fetchOffset": 800,
#
# 			"mendelCookieName": "__mendel",
# 			"mendelCookie": {"pagesViewed":1,"surveyShown":false,"topicInitialSequence":0},
#
#
# 			"autocompleteToSearchPage": false
# 		},
#         "GA": {"leg":"D","userType":"ANONYMOUS","pageType":"Home","gisted":false},
# 		"BC": {
# 			"isInstitutional" : false
# 		}
#     };
#
# 	</script>
#
# <meta property="fb:app_id" content="1887621861548296"/>
#
# 	<meta name="twitter:card" content="summary_large_image" />
# 	<meta name="twitter:site" content="@britannica" />
# 	<meta name="twitter:image" content="https://cdn.britannica.com/mendel-resources/3-105/images/EBLogo.jpg?v=3.105.08" />
# 	<meta name="twitter:description" content="Explore the fact-checked online encyclopedia from Encyclopaedia Britannica with hundreds of thousands of objective articles, biographies, videos, and images from experts."/>
#
# 	<meta property="og:type"  content="WEBSITE"/>
# 	<meta property="og:title" content="Encyclopedia Britannica"/>
# 	<meta property="og:description" content="Explore the fact-checked online encyclopedia from Encyclopaedia Britannica with hundreds of thousands of objective articles, biographies, videos, and images from experts."/>
# 	<meta property="og:site_name" content="Encyclopedia Britannica" />
# 	<meta property="og:url" content="https://www.britannica.com/"/>
# 	<meta property="og:image" content="https://cdn.britannica.com/mendel-resources/3-105/images/EBLogo.jpg?v=3.105.08" />
# 	<meta property="og:image:type" content="" />
#
# 	<script type="text/javascript" data-type="init opengraph">
# 	Mendel.openGraph = {"type":"WEBSITE","title":"Encyclopedia Britannica","description":"Explore the fact-checked online encyclopedia from Encyclopaedia Britannica with hundreds of thousands of objective articles, biographies, videos, and images from experts.","imageUrl":"https://cdn.britannica.com/mendel-resources/3-105/images/EBLogo.jpg?v=3.105.08","pageUrl":"https://www.britannica.com/"}</script>
#
# <link rel="preconnect" href="https://fonts.googleapis.com/">
# <link rel="dns-prefetch" href="https://fonts.googleapis.com/" >
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
# <link href="https://cdn.britannica.com/mendel-resources/3-105/dist/vendor-bundle.css?v=3.105.08" rel="stylesheet" />
#     <link href="https://cdn.britannica.com/mendel-resources/3-105/dist/mendel-css.css?v=3.105.08" rel="stylesheet" />
# 	<link href="https://cdn.britannica.com/mendel-resources/3-105/dist/home-page.css?v=3.105.08" rel="stylesheet" />
#
#     <script type="text/javascript">
#
#
#         if (self !== top) { top.location = self.location; }
#
#
#
#         // if ('scrollRestoration' in history) { history.scrollRestoration = 'manual'; }
#     </script>
#
#     <script
#         src="https://www.googleoptimize.com/optimize.js?id=OPT-TD96PKG"
#         async
#     ></script>
# <script>
# 	            dataLayer = [];
#             </script>
# 		   <script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		   })(window,document,'script','dataLayer','GTM-5W6NC8');
# 		   </script>
# 		</head>
#
# <body data-leg="D" class="homepage user-ANONYMOUS user-ads  md-desktop   leg-d">
#
#     <!-- **** cafemedia **** -->
#
# <script>Mendel.config.adProvider='cafemedia';</script>
# <script>
#   (function (w, d) {
#     w.adthrive = w.adthrive || {};
#     w.adthrive.cmd = w.adthrive.cmd || [];
#     w.adthrive.plugin = 'adthrive-ads-manual';
#     w.adthrive.host = 'ads.adthrive.com';
#
#     var s = d.createElement('script');
#     s.async = true;
#     s.referrerpolicy = 'no-referrer-when-downgrade';
#     s.src = 'https://' + w.adthrive.host + '/sites/61575e5c934c481d714b3ca9/ads.min.js?referrer=' + w.encodeURIComponent(w.location.href) + '&cb=' + Math.floor(Math.random() * 100 + 1);
#     var n = d.getElementsByTagName('script')[0];
#     n.parentNode.insertBefore(s, n);
#   })(window, document);
# </script>
# <script>
#   window.adthrive.cmd.push(function () {
#     const cam_targeting_values = [
#       ...(document.body.classList || [])
#     ];
#     if (cam_targeting_values.length > 0) {
#       window.adthrive.setTargeting({key: 'at_custom_1', value: cam_targeting_values.map(x => 'eb_' + x.toLowerCase().replace(/\s/g, ''))});
#     }
#   });
# </script>
#
#
#
#
#
#
#
# <script  id="json-navbar-info"  type="application/json">
# {"topSectionLinks":[{"title":"Games & Quizzes","url":"/quiz/browse","navbarId":"QUIZZES"},{"title":"History & Society","url":"/History-Society","navbarId":"HISTORY"},{"title":"Science & Tech","url":"/Science-Tech","navbarId":"SCIENCE"},{"title":"Biographies","url":"/Biographies","navbarId":"BIOS"},{"title":"Animals & Nature","url":"/Animals-Nature","navbarId":"ANIMALS"},{"title":"Geography & Travel","url":"/Geography-Travel","navbarId":"GEOGRAPHY"},{"title":"Arts & Culture","url":"/Arts-Culture","navbarId":"ART"},{"title":"Money","url":"/money","navbarId":"MONEY"},{"title":"Videos","url":"/videos","navbarId":"VIDEOS"}],"leftMenu":[{"title":{"id":5,"title":"History & Society","url":"/History-Society"},"links":[{"title":"Lifestyles & Social Issues","url":"/browse/Lifestyles-Social-Issues"},{"title":"Philosophy & Religion","url":"/browse/Philosophy-Religion"},{"title":"Politics, Law & Government","url":"/browse/Politics-Law-Government"},{"title":"World History","url":"/browse/World-History"}]},{"title":{"id":6,"title":"Science & Tech","url":"/Science-Tech"},"links":[{"title":"Health & Medicine","url":"/browse/Health-Medicine"},{"title":"Science","url":"/browse/Science"},{"title":"Technology","url":"/browse/Technology"}]},{"title":{"id":3,"title":"Biographies","url":"/Biographies"},"links":[{"title":"Browse Biographies","url":"/browse/biographies"}]},{"title":{"id":1,"title":"Animals & Nature","url":"/Animals-Nature"},"links":[{"title":"Birds, Reptiles & Other Vertebrates","url":"/browse/Birds-Reptiles-Vertebrates"},{"title":"Bugs, Mollusks & Other Invertebrates","url":"/browse/Bugs-Mollusks-Invertebrates"},{"title":"Environment","url":"/browse/Environment"},{"title":"Fossils & Geologic Time","url":"/browse/Fossil-Geologic-Time"},{"title":"Mammals","url":"/browse/Mammals"},{"title":"Plants","url":"/browse/Plants"}]},{"title":{"id":4,"title":"Geography & Travel","url":"/Geography-Travel"},"links":[{"title":"Geography & Travel","url":"/browse/Geography-Travel"}]},{"title":{"id":2,"title":"Arts & Culture","url":"/Arts-Culture"},"links":[{"title":"Entertainment & Pop Culture","url":"/browse/Entertainment-Pop-Culture"},{"title":"Literature","url":"/browse/Literature"},{"title":"Sports & Recreation","url":"/browse/Sports-Recreation"},{"title":"Visual Arts","url":"/browse/Visual-Arts"}]}]}
# </script>
#
# <header id="header" class="bg-navy-dark">
#   <div class="global-nav-top-bar">
#     <div class="grid gx-0 h-100 justify-content-between align-items-center container-lg mx-auto p-0 position-relative">
#       <!-- menu toggle and top search bar -->
#       <div class="d-flex align-items-center">
#         <button
#           class="d-flex align-items-center justify-self-start js-toggle js-toggle-hamburger btn btn-link link-white btn-sm rounded-0 p-10"
#         >
#         <div class="hamburger-tooltip">
#           <em class="material-icons d-inline-block font-24" id="nav-toggle" data-icon="menu"></em>
#         </div>
#           <em
#
#             class="material-icons d-inline-block font-24 global-nav-search-icon d-none"
#
#             id="nav-search-icon"
#             data-icon="search"
#           ></em>
#           <span id="nav-toggle-text" class="font-14 ml-5 nav-toggle-text">Explore</span>
#             </button>
#         <div class="global-nav-top-search-bar global-nav-top-search-container global-nav-search-container" id="global-nav-top-search-bar">
#               <form method="get" action="/search" id="global-nav-search" class="md-search-form m-0 global-nav-search-bar-small">
#     <div class="search-box position-relative col-100">
#         <label class="sr-only" for="global-nav-search-query">Search Britannica</label>
#         <input name="query" id="global-nav-search-query" placeholder="Search Britannica..." class="form-control form-control-lg rounded-lg font-16 search-query pl-20 pr-70 shadow-sm"  maxlength="200" autocomplete="off"  aria-label="Search Britannica" />
#         <button class="search-reset-btn btn btn-link px-10 position-absolute top-0 h-100 d-none" type="reset">
#             <em class="material-icons" data-icon="close"></em>
#         </button>
#         <button class="search-submit btn btn-link text-blue px-10 position-absolute top-0 right-0 h-100" type="submit" disabled>
#             <span class="sr-only">Click here to search</span>
#             <em class="material-icons search-icon" data-icon="search"></em>
#         </button>
#         </div>
# </form>
# </div>
#           <div class="global-nav-top-search-bar global-nav-top-search-container global-nav-search-container" id="global-nav-top-search-bar">
#           <form method="get" action="/search" id="global-nav-search" class="md-search-form m-0 global-nav-search-bar-small">
#     <div class="search-box position-relative col-100">
#         <label class="sr-only" for="global-nav-search-query">Search Britannica</label>
#         <input name="query" id="global-nav-search-query" placeholder="Search Britannica..." class="form-control form-control-lg rounded-lg font-16 search-query pl-20 pr-70 shadow-sm"  maxlength="200" autocomplete="off"  aria-label="Search Britannica" />
#         <button class="search-reset-btn btn btn-link px-10 position-absolute top-0 h-100 d-none" type="reset">
#             <em class="material-icons" data-icon="close"></em>
#         </button>
#         <button class="search-submit btn btn-link text-blue px-10 position-absolute top-0 right-0 h-100" type="submit" disabled>
#             <span class="sr-only">Click here to search</span>
#             <em class="material-icons search-icon" data-icon="search"></em>
#         </button>
#         </div>
# </form>
# </div>
#       </div>
#
#       <!-- logo/search -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <img loading="lazy" src="https://cdn.britannica.com/mendel/eb-logo/MendelNewThistleLogo.png" alt="Encyclopedia Britannica" class="global-nav-center global-nav-logo"  />
# <!-- login/subscription -->
#       <div class="col-35 col-sm-auto text-right order-3 mr-lg-15 align-items-center d-flex justify-content-end">
#         <button class="js-toggle-user-dropdown js-toggle btn btn-sm btn-link link-white rounded-0 px-md-15 pl-5 pr-5">
#               <span class="d-none d-md-inline-block mr-5">Login</span>
#               <em class="material-icons d-inline-block d-md-none font-16 font-sm-20" data-icon="account_circle"></em>
#               <em class="material-icons inactive-icon d-inline-block font-18" data-icon="keyboard_arrow_down"></em>
# 	<em class="material-icons active-icon d-inline-block font-18" data-icon="keyboard_arrow_up"></em>
# 	</button>
#             <div class="d-none d-md-inline-block">
#               <SPAN class="marketing-HEADER_SUBSCRIPTION_DESKTOP2 marketing-content" data-marketing-id="HEADER_SUBSCRIPTION_DESKTOP2"><a href="https://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=global-nav&utm_campaign=evergreen" class="subscribe-link btn btn-sm btn-orange-dark py-5 mr-10" target="_blank" rel="noopener">
#    Subscribe
# </a></SPAN></div>
#             <div class="d-inline-block d-md-none mr-5 mr-sm-10">
#               <SPAN class="marketing-HEADER_SUBSCRIPTION_MOBILE marketing-content" data-marketing-id="HEADER_SUBSCRIPTION_MOBILE"><a href="https://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=global-nav-mobile&utm_campaign=evergreen" class="subscribe-link btn btn-xs btn-orange-dark p-5" target="_blank" rel="noopener">
#    Subscribe
# </a></SPAN></div>
#           </div>
#     </div>
#   </div>
#
#     <div id="global-nav-react">
#       <div class="d-none">
#         <ul>
#           <li><a href="/quiz/browse">Games & Quizzes</a></li>
#           <li><a href="/History-Society">History & Society</a></li>
#           <li><a href="/Science-Tech">Science & Tech</a></li>
#           <li><a href="/Biographies">Biographies</a></li>
#           <li><a href="/Animals-Nature">Animals & Nature</a></li>
#           <li><a href="/Geography-Travel">Geography & Travel</a></li>
#           <li><a href="/Arts-Culture">Arts & Culture</a></li>
#           <li><a href="/money">Money</a></li>
#           <li><a href="/videos">Videos</a></li>
#           <li><a href="/on-this-day">On This Day</a></li>
#           <li><a href="/one-good-fact">One Good Fact</a></li>
#           <li><a href="/dictionary">Dictionary</a></li>
#           <li><a href="/new-articles">New Articles</a></li>
#         </ul>
#         <a href="/History-Society">History & Society</a>
#           <ul>
#             <li><a href="/browse/Lifestyles-Social-Issues">Lifestyles & Social Issues</a></li>
#             <li><a href="/browse/Philosophy-Religion">Philosophy & Religion</a></li>
#             <li><a href="/browse/Politics-Law-Government">Politics, Law & Government</a></li>
#             <li><a href="/browse/World-History">World History</a></li>
#             </ul>
#         <a href="/Science-Tech">Science & Tech</a>
#           <ul>
#             <li><a href="/browse/Health-Medicine">Health & Medicine</a></li>
#             <li><a href="/browse/Science">Science</a></li>
#             <li><a href="/browse/Technology">Technology</a></li>
#             </ul>
#         <a href="/Biographies">Biographies</a>
#           <ul>
#             <li><a href="/browse/biographies">Browse Biographies</a></li>
#             </ul>
#         <a href="/Animals-Nature">Animals & Nature</a>
#           <ul>
#             <li><a href="/browse/Birds-Reptiles-Vertebrates">Birds, Reptiles & Other Vertebrates</a></li>
#             <li><a href="/browse/Bugs-Mollusks-Invertebrates">Bugs, Mollusks & Other Invertebrates</a></li>
#             <li><a href="/browse/Environment">Environment</a></li>
#             <li><a href="/browse/Fossil-Geologic-Time">Fossils & Geologic Time</a></li>
#             <li><a href="/browse/Mammals">Mammals</a></li>
#             <li><a href="/browse/Plants">Plants</a></li>
#             </ul>
#         <a href="/Geography-Travel">Geography & Travel</a>
#           <ul>
#             <li><a href="/browse/Geography-Travel">Geography & Travel</a></li>
#             </ul>
#         <a href="/Arts-Culture">Arts & Culture</a>
#           <ul>
#             <li><a href="/browse/Entertainment-Pop-Culture">Entertainment & Pop Culture</a></li>
#             <li><a href="/browse/Literature">Literature</a></li>
#             <li><a href="/browse/Sports-Recreation">Sports & Recreation</a></li>
#             <li><a href="/browse/Visual-Arts">Visual Arts</a></li>
#             </ul>
#         <ul>
#           <li><a href="/stories/companion">Companions</a></li>
#           <li><a href="/stories/demystified">Demystified</a></li>
#           <li><a href="/gallery/browse">Image Galleries</a></li>
#           <li><a href="https://www.britannica.com/study/infographics">Infographics</a></li>
#           <li><a href="/list/browse">Lists</a></li>
#           <li><a href="/podcasts">Podcasts</a></li>
#           <li><a href="/stories/spotlight">Spotlights</a></li>
#           <li><a href="/summary">Summaries</a></li>
#           <li><a href="/stories/the-forum">The Forum</a></li>
#           <li><a href="/question">Top Questions</a></li>
#           <li><a href="/stories/wtfact">#WTFact</a></li>
#         </ul>
#         <ul>
#           <li><a href="https://www.britannica.com/explore/100women/" target="_blank">100 Women</a></li>
#           <li><a href="https://kids.britannica.com/" target="_blank">Britannica Kids</a></li>
#           <li><a href="https://www.britannica.com/explore/savingearth/" target="_blank">Saving Earth</a></li>
#           <li><a href="https://www.britannica.com/explore/space/" target="_blank">Space Next 50</a></li>
#           <li><a href="https://www.britannica.com/study/" target="_blank">Student Center</a></li>
#         </ul>
#       </div>
#     </div>
#   </header>
#     <main>
#
# 	    <div class="md-page-wrapper">
#
# 	        <div id="content" class="md-content">
#
# 		        <div class="bg-navy-dark shadow-lg py-5" id="global-nav-homepage-section">
# 			<div class="container-lg">
# 			  <div class="grid">
# 				<div class="col-100 col-sm-80 col-sm-offset-10 col-md-50 col-md-offset-25">
# 				  <div class="global-nav-home-search-container global-nav-search-container">
# 					<form method="get" action="/search" id="global-nav-search" class="md-search-form m-0 ">
#     <div class="search-box position-relative col-100">
#         <label class="sr-only" for="global-nav-search-query">Search Britannica</label>
#         <input name="query" id="global-nav-search-query" placeholder="Search Britannica..." class="form-control form-control-lg rounded-lg font-16 search-query pl-20 pr-70 shadow-sm"  maxlength="200" autocomplete="off"  aria-label="Search Britannica" />
#         <button class="search-reset-btn btn btn-link px-10 position-absolute top-0 h-100 d-none" type="reset">
#             <em class="material-icons" data-icon="close"></em>
#         </button>
#         <button class="search-submit btn btn-link text-blue px-10 position-absolute top-0 right-0 h-100" type="submit" disabled>
#             <span class="sr-only">Click here to search</span>
#             <em class="material-icons search-icon" data-icon="search"></em>
#         </button>
#         </div>
# </form>
# </div>
# 				</div>
# 			  </div>
# 			</div>
# 		  <div class="container-lg p-0 d-flex justify-content-center overflow-hidden">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="slider js-slider position-relative d-inline-flex align-items-center mw-100 mt-20 global-nav-slider category-snap-slider">
#     <div class="slider-container js-slider-container overflow-hidden d-flex font-14 overflow-hidden text-nowrap mx-5">
#
#     <a class="nav-bar-category mx-5 category-link-QUIZZES" href="/quiz/browse">
# 				Games & Quizzes</a><a class="nav-bar-category mx-5 category-link-HISTORY" href="/History-Society">
# 				History & Society</a><a class="nav-bar-category mx-5 category-link-SCIENCE" href="/Science-Tech">
# 				Science & Tech</a><a class="nav-bar-category mx-5 category-link-BIOS" href="/Biographies">
# 				Biographies</a><a class="nav-bar-category mx-5 category-link-ANIMALS" href="/Animals-Nature">
# 				Animals & Nature</a><a class="nav-bar-category mx-5 category-link-GEOGRAPHY" href="/Geography-Travel">
# 				Geography & Travel</a><a class="nav-bar-category mx-5 category-link-ART" href="/Arts-Culture">
# 				Arts & Culture</a><a class="nav-bar-category mx-5 category-link-MONEY" href="/money">
# 				Money</a><a class="nav-bar-category mx-5 category-link-VIDEOS" href="/videos">
# 				Videos</a>
#
#     </div>
#
#
#
#
#
#
#
#     <button disabled class="prev-button js-prev-button position-absolute btn btn-circle shadow  btn-blue " aria-label="Previous">
#         <span class="material-icons md-24" data-icon="keyboard_arrow_left"></span>
#     </button>
#     <button disabled class="next-button js-next-button position-absolute btn btn-circle shadow  btn-blue " aria-label="Next">
#         <span class="material-icons md-24" data-icon="keyboard_arrow_right"></span>
#     </button>
# </div>
#
# </div>
# 		</div>
# 		<div id="homepage-content" itemscope itemtype="https://schema.org/Organization">
#
# 			<meta itemprop="url" content="https://www.britannica.com" />
# 			<meta itemprop="logo" content="https://cdn.britannica.com/mendel-resources/3-105/images/EBLogo.jpg?v=3.105.08" />
# 			<meta itemprop="name" content="Encyclopedia Britannica" />
# 			<meta itemprop="description" content="Explore the fact-checked online encyclopedia from Encyclopaedia Britannica with hundreds of thousands of objective articles, biographies, videos, and images from experts." />
#
# 			<div class="container">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="kic-container qa-contentful1 my-20 ">
#
#
#     <div class="label mb-10">
#
#         <a href="/on-this-day" >
#             November 6, 2023
#         </a>
#     </div>
#
#
#
#
#         <div class="cards3up kic-grid-A2">
#             <div class="kic-title-container">
#                 <h2 class="display-3 font-serif kic-title mb-15">  <a href="https://www.britannica.com/topic/Native-American/Native-American-history" class="md-crosslink" data-show-preview="true">Native American Heritage Month</a>  </h2>
#
#                 <div class="font-serif">
#                     November is National <a href="https://www.britannica.com/topic/Native-American" class="md-crosslink" data-show-preview="true">Native American</a> Heritage Month, a celebration of indigenous cultures—and a chance to <a href="https://www.britannica.com/topic/American-Indian-Movement" class="md-crosslink" data-show-preview="true">correct the narrative</a>. <a href="https://www.britannica.com/topic/National-Museum-of-the-American-Indian/images-videos#/media/1/1000415/181411" class="md-crosslink" data-show-preview="true">Awareness of Native American history</a> has grown since this heritage month <a href="https://www.britannica.com/video/228734/this-month-in-history-November-Native-American-heritage-month" class="md-crosslink" data-show-preview="true">was first observed in 1990</a>. But when you think about how <a href="https://www.britannica.com/topic/Native-American-religion" class="md-crosslink" data-show-preview="true">indigenous cultures</a> were portrayed in history books <a href="https://www.britannica.com/art/western" class="md-crosslink" data-show-preview="true">and Hollywood</a>, there was nowhere to go but up. This November, take a <a href="https://www.britannica.com/topic/National-Museum-of-the-American-Indian/images-videos#/media/1/1000415/181411" class="md-crosslink" data-show-preview="true">moment to reflect</a> on <a href="https://www.britannica.com/topic/Native-American/images-videos#/media/1/1357826/247369" class="md-crosslink" data-show-preview="true">how America’s “settlers”</a> could also be called—<a href="https://www.britannica.com/place/United-States/The-Native-American-response" class="md-crosslink" data-show-preview="true">as a matter of record</a>—invaders.
#                 </div>
#             </div>
#
#
#
#
#
#
#
#                     <div class="card-hero">
#
#
#                         <div class="card ">
#                             <div class="card-media media-VIDEO">
#
#
#                                         <div data-type="video" class="position-relative w-100">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <img loading="eager" src="https://cdn.britannica.com/05/212505-138-59E827CD/Shrinking-Native-American-lands-in-the-United-States-indigenous-peoples.jpg?w=727&h=410&c=crop&q=80" alt="Video on the shrinking of Native American lands in the United States (Native Americans, American Indians, indigenous peoples, land cessation)" class="w-100"   />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             <div class="btn btn-link link-white position-absolute" style="left: 50%; top: 50%; transform: translate3d(-50%, -50%, 0)">
#                                                 <em class="material-icons display-1" data-icon="play_circle_outline"></em>
#                                             </div>
#                                             <script type="application/json">
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/wiWAWhAx.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/05/212505-138-59E827CD/Shrinking-Native-American-lands-in-the-United-States-indigenous-peoples.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/49T2YeUk", "label": "English" } ]
#                                                 }
#                                             </script>
#                                         </div>
#
#
#
#
#                             </div>
#
#                             <div class="card-body mt-10 p-0">
#                                 <a class="font-weight-bold h5" href="/topic/Native-American/images-videos#/media/1/1357826/247369">
# 				How Native Americans Lost Their Land in the United States</a>
#                                 <div class="credit mt-5" style="word-break: break-word;">Encyclopædia Britannica, Inc.</div>
#                             </div>
#                         </div>
#                     </div>
#
#
#
#
#
#                     <div class="card-2">
#
#
#
#
#
#
#
#
#
#                         <div class="card card-horizontal card-sm-vertical">
#                             <div class="card-media media-VIDEO">
#
#
#                                         <div data-type="video" class="position-relative w-100">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <img loading="eager" src="https://cdn.britannica.com/27/233327-138-6322D271/Who-was-Tecumseh.jpg?w=354&h=200&c=crop&q=80" alt="Who was? Tecumseh. Learn about Tecumseh's vision for a Native American confederacy." class="w-100"   />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             <div class="btn btn-link link-white position-absolute" style="left: 50%; top: 50%; transform: translate3d(-50%, -50%, 0)">
#                                                 <em class="material-icons display-1" data-icon="play_circle_outline"></em>
#                                             </div>
#                                             <script type="application/json">
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/1qR63Xmk.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/27/233327-138-6322D271/Who-was-Tecumseh.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/L2kWb27a", "label": "English" } ]
#                                                 }
#                                             </script>
#                                         </div>
#
#
#
#
#                             </div>
#
#                             <div class="card-body mt-10 p-0">
#                                 <a class="font-weight-bold h5" href="/biography/Tecumseh-Shawnee-chief/images-videos#/media/1/585519/270166">
# 				Tecumseh’s Dream of a Native American Confederacy</a>
#                                 <div class="credit mt-5" style="word-break: break-word;">Encyclopaedia Britannica, Inc.</div>
#                             </div>
#                         </div>
#                     </div>
#
#
#
#
#
#                     <div class="card-3">
#
#
#
#
#
#
#
#
#
#                         <div class="card card-horizontal card-sm-vertical">
#                             <div class="card-media media-VIDEO">
#
#
#                                         <div data-type="video" class="position-relative w-100">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <img loading="eager" src="https://cdn.britannica.com/72/233772-138-7B1C1098/who-was-Sitting-Bull.jpg?w=354&h=200&c=crop&q=80" alt="Who was Sitting Bull? Discover the life of Sitting Bull, iconic Native American resistor." class="w-100"   />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             <div class="btn btn-link link-white position-absolute" style="left: 50%; top: 50%; transform: translate3d(-50%, -50%, 0)">
#                                                 <em class="material-icons display-1" data-icon="play_circle_outline"></em>
#                                             </div>
#                                             <script type="application/json">
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/hHFpxbXe.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/72/233772-138-7B1C1098/who-was-Sitting-Bull.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/LkFcE7vn", "label": "English" } ]
#                                                 }
#                                             </script>
#                                         </div>
#
#
#
#
#                             </div>
#
#                             <div class="card-body mt-10 p-0">
#                                 <a class="font-weight-bold h5" href="/biography/Sitting-Bull/images-videos#/media/1/546854/273998">
# 				How Sitting Bull United and Mobilized the Sioux Nation</a>
#                                 <div class="credit mt-5" style="word-break: break-word;">Encyclopaedia Britannica, Inc.</div>
#                             </div>
#                         </div>
#                     </div>
#
#
#
#
#
#
#                 <div class="read-more">
#                     <h3>Discover More</h3>
#                     <div class="grid">
#
#                             <div class="col-sm-50 mb-15 mb-sm-0">
#                                 <a class="font-16 font-weight-bold" href="/list/the-6-nations-of-the-iroquois-confederacy">
# 				The Six Nations of the Iroquois Confederacy</a>
#                             </div>
#
#                             <div class="col-sm-50 mb-15 mb-sm-0">
#                                 <a class="font-16 font-weight-bold" href="/quiz/which-english-words-have-native-american-origins">
# 				Quiz: Which English Words Have Native American Origins?</a>
#                             </div>
#
#                     </div>
#                 </div>
#
#
#             <div class="kic-right-rail kic-right-rail-A2 font-14">
#
#
#
#
#                         <div class="oyr-title-container">
#
#
#
#
#                                 <h3 class="h2 oyr-title font-serif mb-15">  <a href="https://www.britannica.com/biography/James-Naismith" class="md-crosslink" data-show-preview="true">The First Tip Off</a>  </h3>
#
#                             <div class="font-serif">Unlike many other sports, <a href="https://www.britannica.com/biography/James-Naismith" class="md-crosslink" data-show-preview="true">basketball</a> has one definite point of origin—and his name is <a href="https://www.britannica.com/biography/James-Naismith" class="md-crosslink" data-show-preview="true">James Naismith</a> (pictured below), who was born on this day in 1861. Here’s more on basketball’s creator, <a href="https://www.britannica.com/sports/basketball#ref29667" class="md-crosslink" data-show-preview="true">and its evolution</a>.</div>
#                         </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <img loading="eager" src="https://cdn.britannica.com/77/9877-004-8C5A694E/James-Naismith-ball-peach-basket-basketball-equipment.jpg?w=630" alt="" class="oyr-img mt-15 border-sm rounded-sm"   />
#
#
#
#
#
#
#
#
#
#
#                                 <div class="oyr-link-container">
#                                     <a class="oyr-link-title font-weight-bold mt-15 mb-10 d-inline-block" href="/topic/James-Naismith-on-basketball-2215550">
# 				Game plan</a>
#                                     <div class="font-serif">The Canadian-born Naismith was a physical education teacher at a <a href="https://www.britannica.com/topic/YMCA" class="md-crosslink" data-show-preview="true">YMCA</a> Training School in <a href="https://www.britannica.com/place/Springfield-Massachusetts" class="md-crosslink" data-show-preview="true">Springfield, Mass</a>., when, in 1891, he was tasked with creating an indoor game—something more lively than the school’s callisthenics curriculum.</div>
#                                 </div>
#
#
#
#
#
#
#                                 <div class="oyr-link-container">
#                                     <a class="oyr-link-title font-weight-bold mt-15 mb-10 d-inline-block" href="/sports/history-of-basketball">
# 				Home court</a>
#                                     <div class="font-serif">Many of basketball’s fundamental rules can be traced to his first blueprint. Naismith hung the basket off of the gym’s only fixture, a <a href="https://www.britannica.com/story/why-are-basketball-hoops-10-feet-high" class="md-crosslink" data-show-preview="true">railing 10 feet above the floor</a>, which remains the regulation height. His original rules, such as prohibiting walking or running with the ball and limiting physical contact, are still <a href="https://www.britannica.com/sports/basketball/Play-of-the-game" class="md-crosslink" data-show-preview="true">the basis of the game</a>.</div>
#                                 </div>
#
#
#
#
#
#
#                                 <div class="oyr-link-container">
#                                     <a class="oyr-link-title font-weight-bold mt-15 mb-10 d-inline-block" href="/topic/National-Basketball-Association">
# 				Overtime</a>
#                                     <div class="font-serif">Still, there was <a href="https://www.britannica.com/sports/history-of-basketball#ref362089" class="md-crosslink" data-show-preview="true">room for improvement</a>. That first basket was a real basket, so whenever a shot was sunk, somebody had to climb a ladder to retrieve the ball. And each team originally had nine players, because Naismith’s phys-ed class had 18 students. Naismith, though, wasn’t done inventing—he is widely credited as creating the first <a href="https://www.britannica.com/sports/American-football/Managing-the-violence-of-the-game" class="md-crosslink" data-show-preview="true">protective helmet</a> for football players.</div>
#                                 </div>
#
#
#
#
#
#
#
#                     <div class="credit mt-15">UPI/Bettmann Archive</div>
#
#             </div>
#         </div>
#
# </div>
# </div>
#
# 			<div class="container trending-content my-40">
#
# 				<h2 class="mb-15">Popular on <span>Britannica</span></h2>
#
# 				<div class="grid">
#
# 					<div class="trending-list-container qa-treading-articles col-100 col-md-33 mb-30 mb-md-0">
# 							<div class="Articles border-top-5"></div>
# 							<div class="border border-top-0 p-20 py-10 rounded-bl-lg rounded-br-lg">
# 								<h3 class="font-16 text-uppercase mb-15 mb-md-20 d-block">Articles</h3>
# 								<ol>
# 								<li >
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/topic/Guy-Fawkes-Day">Guy Fawkes Day</a>
# 									</li>
# 								<li >
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/place/Bermuda-Triangle">Bermuda Triangle</a>
# 									</li>
# 								<li >
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/technology/artificial-intelligence">artificial intelligence</a>
# 									</li>
# 								<li >
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/topic/Nepal-earthquake-of-2015">Nepal earthquake of 2015</a>
# 									</li>
# 								<li >
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/place/Philippines">Philippines</a>
# 									</li>
# 								<li class="after5 d-none">
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/science/earthquake-geology">earthquake</a>
# 									</li>
# 								<li class="after5 d-none">
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/topic/list-of-state-capitals-in-the-United-States-2119210">list of state capitals in the United States</a>
# 									</li>
# 								<li class="after5 d-none">
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/topic/Thanksgiving-Day">Thanksgiving Day</a>
# 									</li>
# 								<li class="after5 d-none">
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/event/American-Revolution">American Revolution</a>
# 									</li>
# 								<li class="after5 d-none">
# 										<a class="d-block my-10 my-md-15" href="https://www.britannica.com/topic/anti-Semitism">anti-Semitism</a>
# 									</li>
# 								</ol>
# 								<div class="text-center mt-15 mt-md-20">
# 									<button class="trending-show btn btn-sm btn-outline-blue border">
# 										<span class="button-content">Show More <span class="material-icons" data-icon="expand_more"></span></span>
# ...
# 							</div>
# 						</div>
# 					</div>
# 					<div class="col-100 col-sm-50 col-md-25">
# 						<div class="border-red border-top-10 p-20 shadow text-center h-100">
# 							<a class="font-weight-bold font-18" href="https://alainelkanninterviews.com/" target="_blank" rel="noopener">Alain Elkann Interviews</a>
# 							<div class="mt-10 font-serif">Alain has been writing a weekly interview column for the Italian newspaper La Stampa since 1989. His interviews celebrate some of the best known and successful personalities of the present day.</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div></div>
# 	    </div>
# 	</main>
#
#     <div id="md-footer"></div> <footer class="md-footer footer-wrapper hide-on-edit">
#
#     <div class="footer-bck">
#         <DIV class="marketing-FOOTER_NEWSLETTER marketing-content" data-marketing-id="FOOTER_NEWSLETTER"><div class="md-footer-newsletter-form pt-10 mb-30 mx-15 mx-sm-120">
#    <div class="font-18">
#       <strong>History at your fingertips &ndash;</strong>
#       Sign up here to see what happened On This Day, every day in your inbox!
#    </div>
#    <div class="p-30">
#       <div class="newsletter-form-container">
#
#     <form class="newsletter-form" method="post" action="/newsletter-subscription/EB_ON_THIS_DAY">
#
#         <div class="form-group grid d-flex justify-content-center">
#             <div class="col-sm-50 col-100">
#                 <label class="sr-only" for="enter-your-email">Enter your email</label>
#                 <input id="enter-your-email" type="email" name="email" class="form-control font-18 p-10" placeholder="Enter your email" pattern="[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,4}$" required>
#             </div>
#             <div class="col-sm-auto col-100 mt-5 mt-sm-0">
#                 <button type="submit" class="btn btn-outline-white" style="width: 100%; height:100%;">Subscribe</button>
#             </div>
#         </div>
#         <div class="text-white pt-30 text-opacity">
#             By signing up for this email, you are agreeing to news, offers, and information from Encyclopaedia Britannica.<br>
#             Click here to view our <a class="link-white text-decoration-underline" href="https://corporate.britannica.com/privacy-policy" target="_blank" rel="noopener nofollow">Privacy Notice</a>. Easy unsubscribe links are provided in every email.
#         </div>
#
#         <input type="hidden" name="source" value="Footer" /><input type="hidden" name="campaign" value="Mendel" /><input type="hidden" name="medium" value="Box" /></form>
#
#     <div class="md-subscribed hidden text-white">
#        <div class="my-10">Thank you for subscribing!</div>
#        <div>Be on the lookout for your Britannica newsletter to get trusted stories delivered right to your inbox.</div>
#     </div>
#
# </div>
#    </div>
# </div></DIV><div class="footer container">
#     <div class="footer-links grid text-left">
#         <div class="col-100 col-sm-33 col-md-20">
#             <div class="collapse">
#                 <button class="btn btn-link link-white text-uppercase font-weight-bold collapse__toggle">
#                     Our Sites <em class="material-icons " data-icon="keyboard_arrow_down"></em>
# 	</button>
#
#                 <ul class="list-unstyled collapse__body">
#                     <li><a class="link-white" href="https://kids.britannica.com/" rel="noopener" target="_blank">Britannica Kids</a></li>
#                     <li><a class="link-white" href="https://www.merriam-webster.com" rel="noopener" target="_blank">Merriam-Webster</a></li>
# 	                <li><a class="link-white" href="https://britannicalearn.com/" rel="noopener" target="_blank">School &amp; Library</a></li>
# 	                <li><a class="link-white" href="https://books.britannica.com/" rel="noopener" target="_blank">Britannica Books</a></li>
#                     <li><a class="link-white" href="https://escola.britannica.com.br/" rel="noopener" target="_blank">Escola</a><li>
#                     <li><a class="link-white" href="https://arabic.britannicaenglish.com/en/" rel="noopener" target="_blank">Britannica English-Arabic</a><li>
#                     <li><a class="link-white" href="https://www.nglish.com/spanish/en/" rel="noopener" target="_blank">Nglish Sp-En Translation</a><li>
# 	                <li><a class="link-white" href="https://procon.org/" rel="noopener" target="_blank">ProCon</a></li>
# 	                <li><a class="link-white" href="https://britannica.threadless.com/?utm_source=ebsite&utm_medium=footer&utm_campaign=evergreen" rel="noopener" target="_blank">Britannica Merch</a></li>
#                 </ul>
#             </div>
#         </div>
#
#         <div class="col-100 col-sm-33 col-md-20">
#             <div class="collapse">
#                 <button class="btn btn-link link-white text-uppercase font-weight-bold collapse__toggle">
#                     Mobile <em class="material-icons " data-icon="keyboard_arrow_down"></em>
# 	</button>
#
#                 <ul class="list-unstyled collapse__body">
#                     <li><a class="link-white" href="https://itunes.apple.com/us/app/id447919187?mt=8" rel="noopener" target="_blank">iPhone App</a><li>
#                     <li><a class="link-white" href="https://apps.apple.com/us/app/id447919187?platform=ipad" rel="noopener" target="_blank">iPad App</a><li>
#                 </ul>
#             </div>
#         </div>
#
#         <div class="col-100 col-sm-33 col-md-20">
#             <div class="collapse">
#                 <button class="btn btn-link link-white text-uppercase font-weight-bold collapse__toggle">
#                     International <em class="material-icons " data-icon="keyboard_arrow_down"></em>
# 	</button>
#
#                 <ul class="list-unstyled collapse__body">
#                     <li><a class="link-white" href="https://britannica.com.au/" rel="noopener" target="_blank">Australia</a><li>
#                     <li><a class="link-white" href="https://britannica.com.br/" rel="noopener" target="_blank">Brazil</a><li>
#                     <li><a class="link-white" href="https://china.eb.com/" rel="noopener" target="_blank">China</a><li>
#                     <li><a class="link-white" href="https://www.britannica.co.jp/" rel="noopener" target="_blank">Japan</a><li>
#                     <li><a class="link-white" href="https://britannica.es" rel="noopener" target="_blank">Latin America</a><li>
#                     <li><a class="link-white" href="https://britannica.co.uk/" rel="noopener" target="_blank">United Kingdom</a><li>
#                 </ul>
#             </div>
#         </div>
#
#         <div class="col-100 col-sm-33 col-md-20">
#             <div class="collapse">
#                 <button class="btn btn-link link-white text-uppercase font-weight-bold collapse__toggle">
#                     Content &amp; Editorial <em class="material-icons " data-icon="keyboard_arrow_down"></em>
# 	</button>
#
#                 <ul class="list-unstyled collapse__body">
# 	                <li><a class="link-white" href="https://encyclopediaapi.com/" rel="noopener" target="_blank">Encyclopaedia Britannica's Syndication API</a></li>
#                     <li><a class="link-white" href="https://corporate.britannica.com/intl_publishing.html" rel="noopener" target="_blank">International Publishing</a><li>
#                     <li><a class="link-white" href="/sitemap" >Site Map</a><li>
#                     <li><a class="link-white" href="/new-articles">New Articles</a><li>
#                 </ul>
#             </div>
#         </div>
#
#         <div class="col-100 col-sm-33 col-md-20">
#             <div class="collapse">
#                 <button class="btn btn-link link-white text-uppercase font-weight-bold collapse__toggle">
#                     Stay Connected <em class="material-icons " data-icon="keyboard_arrow_down"></em>
# 	</button>
#
#                 <ul class="list-unstyled collapse__body">
#                     <li class="md-footer-social-links">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="md-social-toolbar-circle d-flex justify-content-center grayscale colored"
#      data-value="connect"
#
#
# >
#
#
#         <a class="social-icon facebook justify-content-center d-flex align-items-center align-self-center" data-provider="facebook" href="https://www.facebook.com/BRITANNICA/" target="_blank" rel="noopener"><span>Facebook</span></a>
#
#
#         <a class="social-icon twitter justify-content-center d-flex align-items-center align-self-center" data-provider="twitter" href="https://twitter.com/britannica" target="_blank" rel="noopener"><span>Twitter</span></a>
#
#
#         <a class="social-icon youtube justify-content-center d-flex align-items-center align-self-center" data-provider="youtube" href="https://www.youtube.com/c/encyclopaediabritannica" target="_blank" rel="noopener"><span>YouTube</span></a>
#
#
#         <a class="social-icon instagram justify-content-center d-flex align-items-center align-self-center" data-provider="instagram" href="https://www.instagram.com/britannica/" target="_blank" rel="noopener"><span>Instagram</span></a>
#
#
#         <a class="social-icon pinterest justify-content-center d-flex align-items-center align-self-center" data-provider="pinterest" href="https://www.pinterest.com/britannica/" target="_blank" rel="noopener">
#             <svg height="30" width="30" viewBox="0 0 24 24" aria-hidden="true" aria-label="" role="img"><path d="M0 12c0 5.123 3.211 9.497 7.73 11.218-.11-.937-.227-2.482.025-3.566.217-.932 1.401-5.938 1.401-5.938s-.357-.715-.357-1.774c0-1.66.962-2.9 2.161-2.9 1.02 0 1.512.765 1.512 1.682 0 1.025-.653 2.557-.99 3.978-.281 1.189.597 2.159 1.769 2.159 2.123 0 3.756-2.239 3.756-5.471 0-2.861-2.056-4.86-4.991-4.86-3.398 0-5.393 2.549-5.393 5.184 0 1.027.395 2.127.889 2.726a.36.36 0 0 1 .083.343c-.091.378-.293 1.189-.332 1.355-.053.218-.173.265-.4.159-1.492-.694-2.424-2.875-2.424-4.627 0-3.769 2.737-7.229 7.892-7.229 4.144 0 7.365 2.953 7.365 6.899 0 4.117-2.595 7.431-6.199 7.431-1.211 0-2.348-.63-2.738-1.373 0 0-.599 2.282-.744 2.84-.282 1.084-1.064 2.456-1.549 3.235C9.584 23.815 10.77 24 12 24c6.627 0 12-5.373 12-12S18.627 0 12 0 0 5.373 0 12"></path></svg>
#         </a>
#
#
# </div>
#
#
# </li>
#                 </ul>
#             </div>
#         </div>
#     </div>
#
#     </div>
# <div class="container">
#             <ul class="list-unstyled legal-links">
#                 <li><a href="https://corporate.britannica.com" rel="noopener" target="_blank">About Us & Legal Info</a></li>
#                 <li><a href="https://corporate.britannica.com/contact/" target="_blank" rel="noopener nofollow">Contact Us</a></li>
#                 <li><a href="https://corporate.britannica.com/privacy-policy" target="_blank" rel="noopener nofollow">Privacy Policy</a></li>
#                 <li><a href="https://corporate.britannica.com/termsofuse.html" target="_blank" rel="noopener nofollow">Terms of Use</a></li>
#                 <li><a href="https://corporate.britannica.com/diversity" target="_blank" rel="noopener nofollow">Diversity</a></li>
#                 </ul>
#
#             <div class="mt-20">&copy;2023 Encyclop&aelig;dia Britannica, Inc.</div>
#         </div>
#
#     </div>
#
# </footer>
#
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-5W6NC8" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# 		<script type="text/javascript" id="_informizely_script_tag">
# var IzWidget = IzWidget || {};
# (function (d)
# { var scriptElement = d.createElement('script'); scriptElement.type = 'text/javascript'; scriptElement.async = true; scriptElement.src = "https://insitez.blob.core.windows.net/site/f780f33e-a610-4ac2-af81-3eb184037547.js"; var node = d.getElementById('_informizely_script_tag'); node.parentNode.insertBefore(scriptElement, node); }
# )(document);
# </script>
#
#
#
#
#
#
#
#
#
# <script   class="marketing-page-info" type="application/json">
# {"pageType":"Home","templateName":null,"pageNumber":1,"pagesTotal":1,"pageId":null,"pageLength":null,"initialLoad":true,"lastPageOfScroll":true}
# </script>
#
#
#
#
#
#
#
#
#
# <script   class="marketing-content-info" type="application/json">
# [{"id":1012,"name":"SUBSCRIPTION_LINK_DESKTOP","selector":"#fake"}]
# </script>
#
# <script src="https://cdn.britannica.com/mendel-resources/3-105/js/libs/jquery-3.5.0.min.js?v=3.105.08"></script>
# <script type="application/ld+json">
#             {
#                 "@context": "https://schema.org",
#                 "@type": "WebSite",
#                 "url": "https://www.britannica.com",
#                 "potentialAction": {
#                     "@type": "SearchAction",
#                     "target": "https://www.britannica.com/search?query={search_term}",
#                     "query-input": "required name=search_term"
#                 }
#             }
#         </script><script type="text/javascript" data-type="Init Mendel Code Splitting">
#               (function() {
#                 $.ajax({
#                   dataType: 'script',
#                   cache: true,
#                   url: 'https://cdn.britannica.com/mendel-resources/3-105/dist/home-page.js?v=3.105.08'
#                 });
#               })();
#             </script>
#
#
#
#
#
#
#
#
# <script   class="analytics-metadata" type="application/json">
# {"leg":"D","userType":"ANONYMOUS","pageType":"Home","pageSubtype":null,"articleTemplateType":null,"gisted":false}
# </script>
#
# <script type="text/javascript" src="https://www.googletagmanager.com/gtag/js?id=UA-6636134-11" async="async"></script>
#     <script type="text/javascript">
#
#         function gaPageLoad(pathname, documentLocation) {
#             pathname = pathname || location.pathname;
#             documentLocation = documentLocation || document.querySelector('html').getAttribute('data-ytrk-page');
#
#             if (documentLocation) {
#                 documentLocation = documentLocation.replace(/ /g, '/');
#
#                 if (documentLocation.charAt(0) !== '/') {
#                     documentLocation = '/' + documentLocation;
#                 }
#
#                 window.dataLayer = window.dataLayer || [];
#
#                 function gtag() {
#                     dataLayer.push(arguments);
#                 }
#
#                 gtag('js', new Date());
#
#                 gtag('set', {
#                     'dimension1': 'ANONYMOUS',
#                     'dimension2': 'D',
#                     'dimension3': 'D'
#                 });
#
#                 //console.log( "*****[UA]***** -> ", documentLocation + pathname + decodeURI(location.search) );
#
#                 gtag('config', 'UA-6636134-11', {
#                     'page_path': documentLocation + pathname + decodeURI(location.search),
#                     'link_attribution': true,
#                 });
#             }
#         }
#
#         gaPageLoad();
#     </script>
# <script type="text/javascript">
#     EBStat={accountId:-1,hostnameOverride:'webstats.eb.com',domain:'www.britannica.com', json:''};
#     </script>
#
#     <script type="text/javascript">
#             ( function() {
#                 $.ajax( { dataType: 'script', cache: true, url: '//www.britannica.com/webstats/mendelstats.js?v=1' } )
#                  .done( function() {
#                      try {writeStat(null,EBStat);}
#                      catch(err){}
#                  } );
#             })();
#             </script>
#         <div id="bc-fixed-dialogue"></div>
# <script defer src="https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317" integrity="sha512-euoFGowhlaLqXsPWQ48qSkBSCFs3DPRyiwVu3FjR96cMPx+Fr+gpWRhIafcHwqwCqWS42RZhIudOvEI+Ckf6MA==" data-cf-beacon='{"rayId":"821d5a3b5dfdb08e","b":1,"version":"2023.10.0","token":"5cc7d7124de641b181da990fc8c9a0b6"}' crossorigin="anonymous"></script>
# </body>
# </html>

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Encyclopedia Britannica | Britannica
#
#
#     window.$UI = {};
#
#     window.Constants = {"LICENSE_URL": "/bps/license","DEFAULT_TEST_VERSION": "A","DEFAULT_STATE": "XX","QUIZ_URL": "/quiz","SPOTLIGHT_BROWSE_URL": "/stories/spotlight","CONTENT_TYPE_TEXT": "text/plain;charset=UTF-8","TOPIC_FACTS_DATA_URL": "/facts","QUIZ_BROWSE_IMAGE_QUIZZES": "images","TOPIC_MEDIA_PATH": "/images-videos","USER_PROFILE_URL": "/user","DEBUG_URL": "/debug","ONE_GOOD_FACT_URL": "/one-good-fact","ERROR_404_URL": "/error404","INSTANT_ARTICLES_URL": "/instant-articles","TOPIC_PAGE_CONTENT_AJAX_URL": "/topic-content/page","INFINITE_SCROLL_PREFIX_URL": "/scroll","TOPIC_TOP_QUESTION_BROWSE_URL": "/questions","CC_USD": "USD","domain": "britannica.com","SURVEY_URL": "/survey","PROCON_PAGE_URL": "/procon","CATEGORY_BROWSE_URL": "/browse","STORY_BROWSE_URL": "/stories","COUNTRY_US": "US","OPEN_MEDIA_OVERLAY_PARAMETER": "/media","NEWSLETTER_SUBSCRIPTION_URL": "/newsletter-subscription","INSIGHTS_LANDING_PAGE_URL_2": "/factsmatter","INSIGHTS_LANDING_PAGE_URL_1": "/insights","KUSTOM_MONEY_APPLICATION_ID": "2","MAINTENANCE_ERROR_URL": "https://maintenance.eb.com","IMARS_EDITOR_ID": "12365882","PROFILE_EB_EDITOR_URL": "/editor","WEB_INF_RESOURCES_PATH": "WEB-INF/resources","TOPIC_ADDITIONAL_INFO_PATH": "/additional-info","SUDOKU_GAME_URL": "/games/sudoku","CC_INR": "INR","ARTICLE_PRINT_URL": "/print/article","FIRST_EDITION_URL": "/subscriber/firstedition","WW1_PORTAL_URL": "/discover/World-War-I","MENDEL_COOKIE": "__mendel","DEMYSTIFIED_BROWSE_URL": "/stories/demystified","LIST_BROWSE_URL": "/list/browse","PROFILE_EXPERT_URL": "/contributor","ASSEMBLY_IMAGE_URL": "/image/assembly","DAY_IN_HISTORY_URL": "/on-this-day","DEFAULT_CURRENCY": "USD","CONTENT_TYPE_XML": "text/xml;charset=UTF-8","AJAX_PREFIX_URL": "/ajax","TOPIC_BROWSE_URL": "/topic-browse","MARKETING_CONTENT": "/marketing-content","ENV_RUNTIME": "runtime","GALLERY_URL": "/gallery","REDIRECTED_MONEY_TOPIC_URL_PREFIX": "money/topic","CONTENT_TYPE_HTML": "text/html;charset=UTF-8","ENV_LOCAL": "override","MEDIA_OVERLAY_URL": "/media-overlay","NEWSLETTER_PAGE_URL": "/newsletters","MONEY_SUPERCATEGORY_ID": "7","ENV_DEV": "development","MEDIA_URL": "/media","TOPIC_TOP_QUESTION_URL": "/question","PORTAL_FINANCE_URL_PREFIX": "/money","PODCASTS_URL": "/podcasts","STAND_ALONE_VIDEO_URL": "/video","MORE_ON_THIS_DAY_URL": "/more-on-this-day","TOPIC_QUOTES_URL": "/quotes","SEARCH_PAGE_URL": "/search","KUSTOM_MENDEL_APPLICATION_ID": "1","TOPIC_CONTENT_AJAX_URL": "/topic-content/topic","ENV_BRANCH": "branch","ERROR_URL": "/error","MAIN_VERSION": "mainVersion","DEFAULT_S3_REGION": "US_EAST_1","TOPIC_COLLECTION_URL": "/summary","LOGINBOX_URL": "/auth/loginbox","ONE_GOOD_FACT_BROWSE_URL": "/one-good-fact/all-good-facts","QUIZ_BROWSE_URL": "/quiz/browse","BIO_BROWSE_URL": "/browse/biographies","LIST_URL": "/list","portalRootUrl": "{1=/money}","ALPHA_BROWSE_URL": "/sitemap","CONTENT_TYPE_JSON": "application/json","DICTIONARY_URL": "/dictionary","COBRAND_IMAGE_URL": "/image/cobrand","PROCON_BROWSE_URL": "/procon/browse","QUIZ_BROWSE_VOCAB_QUIZZES": "vocabulary-quizzes","SUBMISSION_URL": "/submission","EB_LOG_OUT": "/auth2/logout","ENV_PRODUCTION": "production","TOPIC_AJAX_URL": "/ajax/topic","TOPIC_SUMMARY_BROWSE_URL": "/summaries","WTFACT_BROWSE_URL": "/stories/wtfact","VIDEO_CHANNEL_URL": "/videos","GALLERY_BROWSE_URL": "/gallery/browse","CACHE_URL": "/cache","COMPANION_BROWSE_URL": "/stories/companion","MEDIA_FOLDER": "/eb-media","SHOW_ALL_CONTRIBUTORS": "/additional-info#contributors","BRITANNICA_EDITORS_ID": "4419","EXPLORE_BROWSE": "/explore","ENV_CACHE_DISABLED": "mendelCache","STORY_URL": "/story","DEFAULT_COUNTRY": "US","NAVBAR_URL": "/ajax/navbar","EB_LOGIN_URL": "/auth/eb-login","NEW_ARTICLES_URL": "/new-articles","topicClasses": "[topic, animal, art, biography, event, place, plant, science, sports, technology]",};
#     window.CDN = "https://cdn.britannica.com";
#     window.CAM_LOGIN_URL = "https://cam.britannica.com";
#     window.CAM_SIGN_UP_URL = "https://cam.britannica.com/registration"
#
#     window.Mendel = {
#      	"config" : {
#       		"domain": "britannica.com",
# 			"page": "Home",
# 			"videoPlayerId": "UyMCoK2v",
# 			"sharedUrl": "https://www.britannica.com/",
# 			"amuselabsUrl": "https://cdn3.amuselabs.com",
# 	    	"resourcesPrefixUrl": "https://cdn.britannica.com/mendel-resources/3-105/[url]?v=3.105.08",
# 			"userInfo": { "type": "ANONYMOUS"
# 			             ,"currency": "USD"
# 			             ,"country": "US"
# 					     ,"state": "SC"
# 			             ,"bcomId": "2894323506733219755"
# 				         ,"hasAds": true
# 					     ,"testVersion": "D"
# 						 ,"adsTestVersion": "D"
# 				         ,"privacyInfo": {"consentLocation":false,"gdpr":false,"ccpa":false,"needConsent":false}
# 						 ,"consumerId": ""
# 						 ,"instId": ""
# 						 ,"consumerUserName": ""
# 						 ,"instUserName": ""
# 						 ,"cognito": null
# 			},
# 			"tvs":{ "r":[2,2,46,50], "a": [2,2,46,50]},
# 			"isLoggedInAsUser": false,
# 			"analytics": {  "gaId": "UA-6636134-11" },
# 			"isPhone": false,
# 			"isDesktop": true,
# 			"logoutUrl": "/auth2/logout",
# 			"selfServiceUrl": "https://myaccount.britannica.com",
# 			"cdnUrl": "https://cdn.britannica.com",
# 	        "fetchOffset": 800,
#
# 			"mendelCookieName": "__mendel",
# 			"mendelCookie": {"pagesViewed":1,"surveyShown":false,"topicInitialSequence":0},
#
#
# 			"autocompleteToSearchPage": false
# 		},
#         "GA": {"leg":"D","userType":"ANONYMOUS","pageType":"Home","gisted":false},
# 		"BC": {
# 			"isInstitutional" : false
# 		}
#     };
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	Mendel.openGraph = {"type":"WEBSITE","title":"Encyclopedia Britannica","description":"Explore the fact-checked online encyclopedia from Encyclopaedia Britannica with hundreds of thousands of objective articles, biographies, videos, and images from experts.","imageUrl":"https://cdn.britannica.com/mendel-resources/3-105/images/EBLogo.jpg?v=3.105.08","pageUrl":"https://www.britannica.com/"}
#
#
#
#
#
#
#
#
#
#
#
#         if (self !== top) { top.location = self.location; }
#
#
#
#         // if ('scrollRestoration' in history) { history.scrollRestoration = 'manual'; }
#
#
#     <script
#         src="https://www.googleoptimize.com/optimize.js?id=OPT-TD96PKG"
#         async
#     >
#
# 	            dataLayer = [];
#
# 		   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		   })(window,document,'script','dataLayer','GTM-5W6NC8');
#
#
#
#
#
#
#
# Mendel.config.adProvider='cafemedia';
#
#   (function (w, d) {
#     w.adthrive = w.adthrive || {};
#     w.adthrive.cmd = w.adthrive.cmd || [];
#     w.adthrive.plugin = 'adthrive-ads-manual';
#     w.adthrive.host = 'ads.adthrive.com';
#
#     var s = d.createElement('script');
#     s.async = true;
#     s.referrerpolicy = 'no-referrer-when-downgrade';
#     s.src = 'https://' + w.adthrive.host + '/sites/61575e5c934c481d714b3ca9/ads.min.js?referrer=' + w.encodeURIComponent(w.location.href) + '&cb=' + Math.floor(Math.random() * 100 + 1);
#     var n = d.getElementsByTagName('script')[0];
#     n.parentNode.insertBefore(s, n);
#   })(window, document);
#
#
#   window.adthrive.cmd.push(function () {
#     const cam_targeting_values = [
#       ...(document.body.classList || [])
#     ];
#     if (cam_targeting_values.length > 0) {
#       window.adthrive.setTargeting({key: 'at_custom_1', value: cam_targeting_values.map(x => 'eb_' + x.toLowerCase().replace(/\s/g, ''))});
#     }
#   });
#
#
#
#
#
#
#
#
#
# {"topSectionLinks":[{"title":"Games & Quizzes","url":"/quiz/browse","navbarId":"QUIZZES"},{"title":"History & Society","url":"/History-Society","navbarId":"HISTORY"},{"title":"Science & Tech","url":"/Science-Tech","navbarId":"SCIENCE"},{"title":"Biographies","url":"/Biographies","navbarId":"BIOS"},{"title":"Animals & Nature","url":"/Animals-Nature","navbarId":"ANIMALS"},{"title":"Geography & Travel","url":"/Geography-Travel","navbarId":"GEOGRAPHY"},{"title":"Arts & Culture","url":"/Arts-Culture","navbarId":"ART"},{"title":"Money","url":"/money","navbarId":"MONEY"},{"title":"Videos","url":"/videos","navbarId":"VIDEOS"}],"leftMenu":[{"title":{"id":5,"title":"History & Society","url":"/History-Society"},"links":[{"title":"Lifestyles & Social Issues","url":"/browse/Lifestyles-Social-Issues"},{"title":"Philosophy & Religion","url":"/browse/Philosophy-Religion"},{"title":"Politics, Law & Government","url":"/browse/Politics-Law-Government"},{"title":"World History","url":"/browse/World-History"}]},{"title":{"id":6,"title":"Science & Tech","url":"/Science-Tech"},"links":[{"title":"Health & Medicine","url":"/browse/Health-Medicine"},{"title":"Science","url":"/browse/Science"},{"title":"Technology","url":"/browse/Technology"}]},{"title":{"id":3,"title":"Biographies","url":"/Biographies"},"links":[{"title":"Browse Biographies","url":"/browse/biographies"}]},{"title":{"id":1,"title":"Animals & Nature","url":"/Animals-Nature"},"links":[{"title":"Birds, Reptiles & Other Vertebrates","url":"/browse/Birds-Reptiles-Vertebrates"},{"title":"Bugs, Mollusks & Other Invertebrates","url":"/browse/Bugs-Mollusks-Invertebrates"},{"title":"Environment","url":"/browse/Environment"},{"title":"Fossils & Geologic Time","url":"/browse/Fossil-Geologic-Time"},{"title":"Mammals","url":"/browse/Mammals"},{"title":"Plants","url":"/browse/Plants"}]},{"title":{"id":4,"title":"Geography & Travel","url":"/Geography-Travel"},"links":[{"title":"Geography & Travel","url":"/browse/Geography-Travel"}]},{"title":{"id":2,"title":"Arts & Culture","url":"/Arts-Culture"},"links":[{"title":"Entertainment & Pop Culture","url":"/browse/Entertainment-Pop-Culture"},{"title":"Literature","url":"/browse/Literature"},{"title":"Sports & Recreation","url":"/browse/Sports-Recreation"},{"title":"Visual Arts","url":"/browse/Visual-Arts"}]}]}
#
#
#
#
#
#
#
#         <button
#           class="d-flex align-items-center justify-self-start js-toggle js-toggle-hamburger btn btn-link link-white btn-sm rounded-0 p-10"
#         >
#
#
#
#           <em
#
#             class="material-icons d-inline-block font-24 global-nav-search-icon d-none"
#
#             id="nav-search-icon"
#             data-icon="search"
#           >
#           Explore
#
#
#
#
#         Search Britannica
#
#
#
#
#
#             Click here to search
#
#
#
#
#
#
#
#
#         Search Britannica
#
#
#
#
#
#             Click here to search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Login
#
#
#
#
#
#
#    Subscribe
#
#
#
#    Subscribe
#
#
#
#
#
#
#
#
#           Games & Quizzes
#           History & Society
#           Science & Tech
#           Biographies
#           Animals & Nature
#           Geography & Travel
#           Arts & Culture
#           Money
#           Videos
#           On This Day
#           One Good Fact
#           Dictionary
#           New Articles
#
#         History & Society
#
#             Lifestyles & Social Issues
#             Philosophy & Religion
#             Politics, Law & Government
#             World History
#
#         Science & Tech
#
#             Health & Medicine
#             Science
#             Technology
#
#         Biographies
#
#             Browse Biographies
#
#         Animals & Nature
#
#             Birds, Reptiles & Other Vertebrates
#             Bugs, Mollusks & Other Invertebrates
#             Environment
#             Fossils & Geologic Time
#             Mammals
#             Plants
#
#         Geography & Travel
#
#             Geography & Travel
#
#         Arts & Culture
#
#             Entertainment & Pop Culture
#             Literature
#             Sports & Recreation
#             Visual Arts
#
#
#           Companions
#           Demystified
#           Image Galleries
#           Infographics
#           Lists
#           Podcasts
#           Spotlights
#           Summaries
#           The Forum
#           Top Questions
#           #WTFact
#
#
#           100 Women
#           Britannica Kids
#           Saving Earth
#           Space Next 50
#           Student Center
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search Britannica
#
#
#
#
#
#             Click here to search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Games & Quizzes
# 				History & Society
# 				Science & Tech
# 				Biographies
# 				Animals & Nature
# 				Geography & Travel
# 				Arts & Culture
# 				Money
# 				Videos
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             November 6, 2023
#
#
#
#
#
#
#
#
#                   Native American Heritage Month
#
#
#                     November is National Native American Heritage Month, a celebration of indigenous cultures—and a chance to correct the narrative. Awareness of Native American history has grown since this heritage month was first observed in 1990. But when you think about how indigenous cultures were portrayed in history books and Hollywood, there was nowhere to go but up. This November, take a moment to reflect on how America’s “settlers” could also be called—as a matter of record—invaders.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/wiWAWhAx.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/05/212505-138-59E827CD/Shrinking-Native-American-lands-in-the-United-States-indigenous-peoples.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/49T2YeUk", "label": "English" } ]
#                                                 }
#
#
#
#
#
#
#
#
#
#
# 				How Native Americans Lost Their Land in the United States
#                                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/1qR63Xmk.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/27/233327-138-6322D271/Who-was-Tecumseh.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/L2kWb27a", "label": "English" } ]
#                                                 }
#
#
#
#
#
#
#
#
#
#
# 				Tecumseh’s Dream of a Native American Confederacy
#                                 Encyclopaedia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/hHFpxbXe.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/72/233772-138-7B1C1098/who-was-Sitting-Bull.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/LkFcE7vn", "label": "English" } ]
#                                                 }
#
#
#
#
#
#
#
#
#
#
# 				How Sitting Bull United and Mobilized the Sioux Nation
#                                 Encyclopaedia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#                     Discover More
#
#
#
#
# 				The Six Nations of the Iroquois Confederacy
#
#
#
#
# 				Quiz: Which English Words Have Native American Origins?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                   The First Tip Off
#
#                             Unlike many other sports, basketball has one definite point of origin—and his name is James Naismith (pictured below), who was born on this day in 1861. Here’s more on basketball’s creator, and its evolution.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Game plan
#                                     The Canadian-born Naismith was a physical education teacher at a YMCA Training School in Springfield, Mass., when, in 1891, he was tasked with creating an indoor game—something more lively than the school’s callisthenics curriculum.
#
#
#
#
#
#
#
#
#
# 				Home court
#                                     Many of basketball’s fundamental rules can be traced to his first blueprint. Naismith hung the basket off of the gym’s only fixture, a railing 10 feet above the floor, which remains the regulation height. His original rules, such as prohibiting walking or running with the ball and limiting physical contact, are still the basis of the game.
#
#
#
#
#
#
#
#
#
# 				Overtime
#                                     Still, there was room for improvement. That first basket was a real basket, so whenever a shot was sunk, somebody had to climb a ladder to retrieve the ball. And each team originally had nine players, because Naismith’s phys-ed class had 18 students. Naismith, though, wasn’t done inventing—he is widely credited as creating the first protective helmet for football players.
#
#
#
#
#
#
#
#
#                     UPI/Bettmann Archive
#
#
#
#
#
#
#
#
#
# 				Popular on Britannica
#
#
#
#
#
#
# 								Articles
#
#
# 										Guy Fawkes Day
#
#
# 										Bermuda Triangle
#
#
# 										artificial intelligence
#
#
# 										Nepal earthquake of 2015
#
#
# 										Philippines
#
#
# 										earthquake
#
#
# 										list of state capitals in the United States
#
#
# 										Thanksgiving Day
#
#
# 										American Revolution
#
#
# 										anti-Semitism
#
#
#
#
# 										Show More
# 										Show Less
#
#
#
#
#
#
#
#
# 								Features
#
#
# 										Why Do We Celebrate Halloween?
#
#
# 										Why Is It Called Black Friday?
#
#
# 										How Mike the Chicken Survived Without a Head
#
#
# 										What Is Known (and Not Known) About the Bermuda Triangle
#
#
# 										Where Does the Concept of a “Grim Reaper” Come From?
#
#
# 										Pro and Con: School Uniforms
#
#
# 										How Many Electoral College Votes Does Each U.S. State Have?&nbsp;
#
#
# 										Feliz Día de los Muertos
#
#
# 										History of Technology Timeline
#
#
# 										26 Decade-Defining Events in U.S. History
#
#
#
#
# 										Show More
# 										Show Less
#
#
#
#
#
#
#
#
# 								Lists
#
#
# 										6 Animals We Ate Into Extinction
#
#
# 										7 of History's Most Notorious Serial Killers&nbsp;
#
#
# 										Timeline of the American Revolution
#
#
# 										6 Wars of Independence
#
#
# 										9 Noteworthy Bog Bodies (And What They Tell Us)
#
#
# 										Inventors and Inventions of the Industrial Revolution
#
#
# 										10 Famous Artworks by Leonardo da Vinci
#
#
# 										11 Egyptian Gods and Goddesses
#
#
# 										The 6 Deadliest Earthquakes Since 1950
#
#
# 										9 Things You Might Not Know About Adolf Hitler
#
#
#
#
# 										Show More
# 										Show Less
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 							Household Finance
#
#
# 							Investing
#
#
# 							Retirement
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Social Security COLA 2024: What you need to know
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		What is stagflation? A double whammy of headwinds
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Certificate of deposit (CD) vs. savings account: How to choose
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Will vs. living trust: What’s the difference?
#
#
#
#
#
#
#
#
#
#
#
# 						  New on Britannica
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												15 of the best birdsongs
#
# 												Check out this collection of birdsongs to help identify which bird is behind those chirps you hear so often.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												Human composting
#
# 												This new type of alternative burial rite turns human remains into soil or compost over a period of 60 to 90 days.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												How wireless earbuds work
#
# 												You use them all the time but have you ever stopped to think about the science behind how those wireless earbuds work?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												Government shutdown
#
# 												As Congress heads toward a government shutdown, here’s a breakdown of how and why these things occur.
#
#
#
#
#
#
#
#
#
# 				Trending Quizzes
# 				See All Quizzes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Where in America is That?
#
#
# 						Crisscross the U.S. by placing these famous landmarks.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				From Athena to Zeus: Basics of Greek Mythology
#
#
# 						Do you know which hero took a dip in the River Styx? Or what mysteries lurk inside the Labyrinth?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Ultimate Animals Quiz
#
#
# 						What is a rattlesnake’s rattle made of? What animals can go over 180 miles an hour?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Guess the Language! Quiz
#
#
# 						Can you recognize a language by its greeting?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Best Picture Movie Quote Quiz
#
#
# 						Take this quiz or you may regret it. Maybe not today, maybe not tomorrow, but soon, and for the rest of your life.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				American Civil Rights Movement Quiz
#
#
# 						Test your knowledge of Americans’ tumultuous fight to end racial segregation and discrimination.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Name That Thing: Tools
#
#
# 						A handy quiz to test your tool acumen.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				The Dog Breed Quiz
#
#
# 						Find out which breed can outrun a cheetah, which breed was created by monks, and much more.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Baking and Baked Goods Quiz
#
#
# 						You may have a sweet tooth, but how much do you know about baking and baked goods? Test your knowledge with this quiz.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				First Ladies of the United States Quiz
#
#
# 						They have been hostesses, helpers, advisers, gatekeepers, guardians, confidantes, and sometimes formidable powers behind...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					 Featured Videos
# 					 See All Videos
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             A look behind the curtain in Edgar Degas's The Ballet Class
#
#
#
#             Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/82/248782-138-842428B7/The-Ballet-Class-Edgar-Degas.jpg","sources":[{"file":"//content.jwplatform.com/manifests/hToaxhsn.m3u8"}],"assetId":248782,"adfile":"//content.jwplatform.com/manifests/a0dMagtb.m3u8","title":"A look behind the curtain in Edgar Degas's The Ballet Class","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/3rADrCUY.vtt","label":"English"}],"transcriptUrl":"/video/248782/The-Ballet-Class-Edgar-Degas#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		A look behind the curtain in Edgar Degas's The Ballet Class
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/60/250260-138-09F49202/Paris-Street-Rainy-Day-Gustave-Caillebotte-1877.jpg","sources":[{"file":"//content.jwplatform.com/manifests/MZGUibb3.m3u8"}],"assetId":250260,"adfile":"//content.jwplatform.com/manifests/f21gLhye.m3u8","title":"Paris Street; Rainy Day and a vision of the modern city","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/Z7DTvFo5.vtt","label":"English"}],"transcriptUrl":"/video/250260/Paris-Street-Rainy-Day-Gustave-Caillebotte-1877#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Paris Street; Rainy Day and a vision of the modern city
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/48/249448-138-E091CC5D/Nocturne-in-Black-and-Gold-the-Falling-Rocket-James-McNeill-Whistler.jpg","sources":[{"file":"//content.jwplatform.com/manifests/FS4aAnsf.m3u8"}],"assetId":249448,"adfile":"//content.jwplatform.com/manifests/RBR8T6rY.m3u8","title":"Why was Nocturne in Black and Gold, the Falling Rocket controversial?","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/QgCXssEQ.vtt","label":"English"}],"transcriptUrl":"/video/249448/Nocturne-in-Black-and-Gold-the-Falling-Rocket-James-McNeill-Whistler#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Why was Nocturne in Black and Gold, the Falling Rocket controversial?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/87/248787-138-B1190CE9/Beauty-Looking-Back-Hishikawa-Moronobu.jpg","sources":[{"file":"//content.jwplatform.com/manifests/Mbi1vLjY.m3u8"}],"assetId":248787,"adfile":"//content.jwplatform.com/manifests/k0COsWtO.m3u8","title":"How Beauty Looking Back reflects Japanese history","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/02hbRCkE.vtt","label":"English"}],"transcriptUrl":"/video/248787/Beauty-Looking-Back-Hishikawa-Moronobu#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		How Beauty Looking Back reflects Japanese history
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Explore Britannica
#
#
#
#
#
# 				History & Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		6 Wars of Independence
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		5 of the World’s Most Devastating Financial Crises
#
#
#
#
#
#
#
#
# 				Science & Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		The Major Mass Extinctions That Shaped Life on Earth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Do Lie Detectors Actually Work?
#
#
#
#
#
#
#
#
# 				Biographies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Matthew Perry
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Marie Laveau
#
#
#
#
#
#
#
#
# 				Animals & Nature
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		7 Brilliant Ways Seeds and Fruits Are Dispersed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		The Horseshoe Crab: a Key Player in Ecology and Medicine
#
#
#
#
#
#
#
#
# 				Geography & Travel
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Palestine
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		How Long Is the Amazon River?
#
#
#
#
#
#
#
#
# 				Arts & Culture
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		9 Muses Who Were Artists
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Street Photography: How a Single Camera Created a Genre
#
#
#
#
#
#
#
#
#
# 				More From Britannica
#
#
#
# 							ProCon.org
# 							Award-winning ProCon.org promotes critical thinking, education, and informed citizenship by presenting the pro and con arguments to controversial issues in a straightforward, nonpartisan, freely accessible way.
#
#
#
#
# 							Britannica Money
# 							Discover all you need to know about retirement, investing, and household finance, without the jargon or agenda. Get reliable guidance, insight, and easy-to-understand explanations, written, edited, and verified to Britannica’s exacting standards.
#
#
#
#
# 							Advocacy for Animals
#
# 								Presenting Advocacy for Animals, a blog focused primarily on animal rights, wildlife conservation, environmental health and safety, and the legal and cultural issues related to these topics.  This blog is a source of information and a call to action. It is meant to be a provocation and a stimulus to thought regarding humanity’s relationship with nonhuman animals.
#
#
#
#
#
# 							Alain Elkann Interviews
# 							Alain has been writing a weekly interview column for the Italian newspaper La Stampa since 1989. His interviews celebrate some of the best known and successful personalities of the present day.
#
#
#
#
#
#
#
#
#
#
#
#
#
#       History at your fingertips &ndash;
#       Sign up here to see what happened On This Day, every day in your inbox!
#
#
#
#
#
#
#
#
#                 Enter your email
#
#
#
#                 Subscribe
#
#
#
#             By signing up for this email, you are agreeing to news, offers, and information from Encyclopaedia Britannica.
#             Click here to view our Privacy Notice. Easy unsubscribe links are provided in every email.
#
#
#
#
#
#        Thank you for subscribing!
#        Be on the lookout for your Britannica newsletter to get trusted stories delivered right to your inbox.
#
#
#
#
#
#
#
#
#
#                     Our Sites
#
#
#
#                     Britannica Kids
#                     Merriam-Webster
# 	                School &amp; Library
# 	                Britannica Books
#                     Escola
#                     Britannica English-Arabic
#                     Nglish Sp-En Translation
# 	                ProCon
# 	                Britannica Merch
#
#
#
#
#
#
#
#                     Mobile
#
#
#
#                     iPhone App
#                     iPad App
#
#
#
#
#
#
#
#                     International
#
#
#
#                     Australia
#                     Brazil
#                     China
#                     Japan
#                     Latin America
#                     United Kingdom
#
#
#
#
#
#
#
#                     Content &amp; Editorial
#
#
#
# 	                Encyclopaedia Britannica's Syndication API
#                     International Publishing
#                     Site Map
#                     New Articles
#
#
#
#
#
#
#
#                     Stay Connected
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="md-social-toolbar-circle d-flex justify-content-center grayscale colored"
#      data-value="connect"
#
#
# >
#
#
#         Facebook
#
#
#         Twitter
#
#
#         YouTube
#
#
#         Instagram
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 About Us & Legal Info
#                 Contact Us
#                 Privacy Policy
#                 Terms of Use
#                 Diversity
#
#
#             &copy;2023 Encyclop&aelig;dia Britannica, Inc.
#
#
#
#
#
#
#
#
# var IzWidget = IzWidget || {};
# (function (d)
# { var scriptElement = d.createElement('script'); scriptElement.type = 'text/javascript'; scriptElement.async = true; scriptElement.src = "https://insitez.blob.core.windows.net/site/f780f33e-a610-4ac2-af81-3eb184037547.js"; var node = d.getElementById('_informizely_script_tag'); node.parentNode.insertBefore(scriptElement, node); }
# )(document);
#
#
#
#
#
#
#
#
#
#
#
# {"pageType":"Home","templateName":null,"pageNumber":1,"pagesTotal":1,"pageId":null,"pageLength":null,"initialLoad":true,"lastPageOfScroll":true}
#
#
#
#
#
#
#
#
#
#
#
# [{"id":1012,"name":"SUBSCRIPTION_LINK_DESKTOP","selector":"#fake"}]
#
#
#
#
#             {
#                 "@context": "https://schema.org",
#                 "@type": "WebSite",
#                 "url": "https://www.britannica.com",
#                 "potentialAction": {
#                     "@type": "SearchAction",
#                     "target": "https://www.britannica.com/search?query={search_term}",
#                     "query-input": "required name=search_term"
#                 }
#             }
#
#               (function() {
#                 $.ajax({
#                   dataType: 'script',
#                   cache: true,
#                   url: 'https://cdn.britannica.com/mendel-resources/3-105/dist/home-page.js?v=3.105.08'
#                 });
#               })();
#
#
#
#
#
#
#
#
#
#
# {"leg":"D","userType":"ANONYMOUS","pageType":"Home","pageSubtype":null,"articleTemplateType":null,"gisted":false}
#
#
#
#
#
#         function gaPageLoad(pathname, documentLocation) {
#             pathname = pathname || location.pathname;
#             documentLocation = documentLocation || document.querySelector('html').getAttribute('data-ytrk-page');
#
#             if (documentLocation) {
#                 documentLocation = documentLocation.replace(/ /g, '/');
#
#                 if (documentLocation.charAt(0) !== '/') {
#                     documentLocation = '/' + documentLocation;
#                 }
#
#                 window.dataLayer = window.dataLayer || [];
#
#                 function gtag() {
#                     dataLayer.push(arguments);
#                 }
#
#                 gtag('js', new Date());
#
#                 gtag('set', {
#                     'dimension1': 'ANONYMOUS',
#                     'dimension2': 'D',
#                     'dimension3': 'D'
#                 });
#
#                 //console.log( "*****[UA]***** -> ", documentLocation + pathname + decodeURI(location.search) );
#
#                 gtag('config', 'UA-6636134-11', {
#                     'page_path': documentLocation + pathname + decodeURI(location.search),
#                     'link_attribution': true,
#                 });
#             }
#         }
#
#         gaPageLoad();
#
#
#     EBStat={accountId:-1,hostnameOverride:'webstats.eb.com',domain:'www.britannica.com', json:''};
#
#
#
#             ( function() {
#                 $.ajax( { dataType: 'script', cache: true, url: '//www.britannica.com/webstats/mendelstats.js?v=1' } )
#                  .done( function() {
#                      try {writeStat(null,EBStat);}
#                      catch(err){}
#                  } );
#             })();

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Encyclopedia Britannica | Britannica
#
#
#     window.$UI = {};
#
#     window.Constants = {"LICENSE_URL": "/bps/license","DEFAULT_TEST_VERSION": "A","DEFAULT_STATE": "XX","QUIZ_URL": "/quiz","SPOTLIGHT_BROWSE_URL": "/stories/spotlight","CONTENT_TYPE_TEXT": "text/plain;charset=UTF-8","TOPIC_FACTS_DATA_URL": "/facts","QUIZ_BROWSE_IMAGE_QUIZZES": "images","TOPIC_MEDIA_PATH": "/images-videos","USER_PROFILE_URL": "/user","DEBUG_URL": "/debug","ONE_GOOD_FACT_URL": "/one-good-fact","ERROR_404_URL": "/error404","INSTANT_ARTICLES_URL": "/instant-articles","TOPIC_PAGE_CONTENT_AJAX_URL": "/topic-content/page","INFINITE_SCROLL_PREFIX_URL": "/scroll","TOPIC_TOP_QUESTION_BROWSE_URL": "/questions","CC_USD": "USD","domain": "britannica.com","SURVEY_URL": "/survey","PROCON_PAGE_URL": "/procon","CATEGORY_BROWSE_URL": "/browse","STORY_BROWSE_URL": "/stories","COUNTRY_US": "US","OPEN_MEDIA_OVERLAY_PARAMETER": "/media","NEWSLETTER_SUBSCRIPTION_URL": "/newsletter-subscription","INSIGHTS_LANDING_PAGE_URL_2": "/factsmatter","INSIGHTS_LANDING_PAGE_URL_1": "/insights","KUSTOM_MONEY_APPLICATION_ID": "2","MAINTENANCE_ERROR_URL": "https://maintenance.eb.com","IMARS_EDITOR_ID": "12365882","PROFILE_EB_EDITOR_URL": "/editor","WEB_INF_RESOURCES_PATH": "WEB-INF/resources","TOPIC_ADDITIONAL_INFO_PATH": "/additional-info","SUDOKU_GAME_URL": "/games/sudoku","CC_INR": "INR","ARTICLE_PRINT_URL": "/print/article","FIRST_EDITION_URL": "/subscriber/firstedition","WW1_PORTAL_URL": "/discover/World-War-I","MENDEL_COOKIE": "__mendel","DEMYSTIFIED_BROWSE_URL": "/stories/demystified","LIST_BROWSE_URL": "/list/browse","PROFILE_EXPERT_URL": "/contributor","ASSEMBLY_IMAGE_URL": "/image/assembly","DAY_IN_HISTORY_URL": "/on-this-day","DEFAULT_CURRENCY": "USD","CONTENT_TYPE_XML": "text/xml;charset=UTF-8","AJAX_PREFIX_URL": "/ajax","TOPIC_BROWSE_URL": "/topic-browse","MARKETING_CONTENT": "/marketing-content","ENV_RUNTIME": "runtime","GALLERY_URL": "/gallery","REDIRECTED_MONEY_TOPIC_URL_PREFIX": "money/topic","CONTENT_TYPE_HTML": "text/html;charset=UTF-8","ENV_LOCAL": "override","MEDIA_OVERLAY_URL": "/media-overlay","NEWSLETTER_PAGE_URL": "/newsletters","MONEY_SUPERCATEGORY_ID": "7","ENV_DEV": "development","MEDIA_URL": "/media","TOPIC_TOP_QUESTION_URL": "/question","PORTAL_FINANCE_URL_PREFIX": "/money","PODCASTS_URL": "/podcasts","STAND_ALONE_VIDEO_URL": "/video","MORE_ON_THIS_DAY_URL": "/more-on-this-day","TOPIC_QUOTES_URL": "/quotes","SEARCH_PAGE_URL": "/search","KUSTOM_MENDEL_APPLICATION_ID": "1","TOPIC_CONTENT_AJAX_URL": "/topic-content/topic","ENV_BRANCH": "branch","ERROR_URL": "/error","MAIN_VERSION": "mainVersion","DEFAULT_S3_REGION": "US_EAST_1","TOPIC_COLLECTION_URL": "/summary","LOGINBOX_URL": "/auth/loginbox","ONE_GOOD_FACT_BROWSE_URL": "/one-good-fact/all-good-facts","QUIZ_BROWSE_URL": "/quiz/browse","BIO_BROWSE_URL": "/browse/biographies","LIST_URL": "/list","portalRootUrl": "{1=/money}","ALPHA_BROWSE_URL": "/sitemap","CONTENT_TYPE_JSON": "application/json","DICTIONARY_URL": "/dictionary","COBRAND_IMAGE_URL": "/image/cobrand","PROCON_BROWSE_URL": "/procon/browse","QUIZ_BROWSE_VOCAB_QUIZZES": "vocabulary-quizzes","SUBMISSION_URL": "/submission","EB_LOG_OUT": "/auth2/logout","ENV_PRODUCTION": "production","TOPIC_AJAX_URL": "/ajax/topic","TOPIC_SUMMARY_BROWSE_URL": "/summaries","WTFACT_BROWSE_URL": "/stories/wtfact","VIDEO_CHANNEL_URL": "/videos","GALLERY_BROWSE_URL": "/gallery/browse","CACHE_URL": "/cache","COMPANION_BROWSE_URL": "/stories/companion","MEDIA_FOLDER": "/eb-media","SHOW_ALL_CONTRIBUTORS": "/additional-info#contributors","BRITANNICA_EDITORS_ID": "4419","EXPLORE_BROWSE": "/explore","ENV_CACHE_DISABLED": "mendelCache","STORY_URL": "/story","DEFAULT_COUNTRY": "US","NAVBAR_URL": "/ajax/navbar","EB_LOGIN_URL": "/auth/eb-login","NEW_ARTICLES_URL": "/new-articles","topicClasses": "[topic, animal, art, biography, event, place, plant, science, sports, technology]",};
#     window.CDN = "https://cdn.britannica.com";
#     window.CAM_LOGIN_URL = "https://cam.britannica.com";
#     window.CAM_SIGN_UP_URL = "https://cam.britannica.com/registration"
#
#     window.Mendel = {
#      	"config" : {
#       		"domain": "britannica.com",
# 			"page": "Home",
# 			"videoPlayerId": "UyMCoK2v",
# 			"sharedUrl": "https://www.britannica.com/",
# 			"amuselabsUrl": "https://cdn3.amuselabs.com",
# 	    	"resourcesPrefixUrl": "https://cdn.britannica.com/mendel-resources/3-105/[url]?v=3.105.08",
# 			"userInfo": { "type": "ANONYMOUS"
# 			             ,"currency": "USD"
# 			             ,"country": "US"
# 					     ,"state": "SC"
# 			             ,"bcomId": "2894323506733219755"
# 				         ,"hasAds": true
# 					     ,"testVersion": "D"
# 						 ,"adsTestVersion": "D"
# 				         ,"privacyInfo": {"consentLocation":false,"gdpr":false,"ccpa":false,"needConsent":false}
# 						 ,"consumerId": ""
# 						 ,"instId": ""
# 						 ,"consumerUserName": ""
# 						 ,"instUserName": ""
# 						 ,"cognito": null
# 			},
# 			"tvs":{ "r":[2,2,46,50], "a": [2,2,46,50]},
# 			"isLoggedInAsUser": false,
# 			"analytics": {  "gaId": "UA-6636134-11" },
# 			"isPhone": false,
# 			"isDesktop": true,
# 			"logoutUrl": "/auth2/logout",
# 			"selfServiceUrl": "https://myaccount.britannica.com",
# 			"cdnUrl": "https://cdn.britannica.com",
# 	        "fetchOffset": 800,
#
# 			"mendelCookieName": "__mendel",
# 			"mendelCookie": {"pagesViewed":1,"surveyShown":false,"topicInitialSequence":0},
#
#
# 			"autocompleteToSearchPage": false
# 		},
#         "GA": {"leg":"D","userType":"ANONYMOUS","pageType":"Home","gisted":false},
# 		"BC": {
# 			"isInstitutional" : false
# 		}
#     };
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	Mendel.openGraph = {"type":"WEBSITE","title":"Encyclopedia Britannica","description":"Explore the fact-checked online encyclopedia from Encyclopaedia Britannica with hundreds of thousands of objective articles, biographies, videos, and images from experts.","imageUrl":"https://cdn.britannica.com/mendel-resources/3-105/images/EBLogo.jpg?v=3.105.08","pageUrl":"https://www.britannica.com/"}
#
#
#
#
#
#
#
#
#
#
#
#         if (self !== top) { top.location = self.location; }
#
#
#
#         // if ('scrollRestoration' in history) { history.scrollRestoration = 'manual'; }
#
#
#
#
# 	            dataLayer = [];
#
# 		   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		   })(window,document,'script','dataLayer','GTM-5W6NC8');
#
#
#
#
#
#
#
# Mendel.config.adProvider='cafemedia';
#
#   (function (w, d) {
#     w.adthrive = w.adthrive || {};
#     w.adthrive.cmd = w.adthrive.cmd || [];
#     w.adthrive.plugin = 'adthrive-ads-manual';
#     w.adthrive.host = 'ads.adthrive.com';
#
#     var s = d.createElement('script');
#     s.async = true;
#     s.referrerpolicy = 'no-referrer-when-downgrade';
#     s.src = 'https://' + w.adthrive.host + '/sites/61575e5c934c481d714b3ca9/ads.min.js?referrer=' + w.encodeURIComponent(w.location.href) + '&cb=' + Math.floor(Math.random() * 100 + 1);
#     var n = d.getElementsByTagName('script')[0];
#     n.parentNode.insertBefore(s, n);
#   })(window, document);
#
#
#   window.adthrive.cmd.push(function () {
#     const cam_targeting_values = [
#       ...(document.body.classList || [])
#     ];
#     if (cam_targeting_values.length > 0) {
#       window.adthrive.setTargeting({key: 'at_custom_1', value: cam_targeting_values.map(x => 'eb_' + x.toLowerCase().replace(/\s/g, ''))});
#     }
#   });
#
#
#
#
#
#
#
#
#
# {"topSectionLinks":[{"title":"Games & Quizzes","url":"/quiz/browse","navbarId":"QUIZZES"},{"title":"History & Society","url":"/History-Society","navbarId":"HISTORY"},{"title":"Science & Tech","url":"/Science-Tech","navbarId":"SCIENCE"},{"title":"Biographies","url":"/Biographies","navbarId":"BIOS"},{"title":"Animals & Nature","url":"/Animals-Nature","navbarId":"ANIMALS"},{"title":"Geography & Travel","url":"/Geography-Travel","navbarId":"GEOGRAPHY"},{"title":"Arts & Culture","url":"/Arts-Culture","navbarId":"ART"},{"title":"Money","url":"/money","navbarId":"MONEY"},{"title":"Videos","url":"/videos","navbarId":"VIDEOS"}],"leftMenu":[{"title":{"id":5,"title":"History & Society","url":"/History-Society"},"links":[{"title":"Lifestyles & Social Issues","url":"/browse/Lifestyles-Social-Issues"},{"title":"Philosophy & Religion","url":"/browse/Philosophy-Religion"},{"title":"Politics, Law & Government","url":"/browse/Politics-Law-Government"},{"title":"World History","url":"/browse/World-History"}]},{"title":{"id":6,"title":"Science & Tech","url":"/Science-Tech"},"links":[{"title":"Health & Medicine","url":"/browse/Health-Medicine"},{"title":"Science","url":"/browse/Science"},{"title":"Technology","url":"/browse/Technology"}]},{"title":{"id":3,"title":"Biographies","url":"/Biographies"},"links":[{"title":"Browse Biographies","url":"/browse/biographies"}]},{"title":{"id":1,"title":"Animals & Nature","url":"/Animals-Nature"},"links":[{"title":"Birds, Reptiles & Other Vertebrates","url":"/browse/Birds-Reptiles-Vertebrates"},{"title":"Bugs, Mollusks & Other Invertebrates","url":"/browse/Bugs-Mollusks-Invertebrates"},{"title":"Environment","url":"/browse/Environment"},{"title":"Fossils & Geologic Time","url":"/browse/Fossil-Geologic-Time"},{"title":"Mammals","url":"/browse/Mammals"},{"title":"Plants","url":"/browse/Plants"}]},{"title":{"id":4,"title":"Geography & Travel","url":"/Geography-Travel"},"links":[{"title":"Geography & Travel","url":"/browse/Geography-Travel"}]},{"title":{"id":2,"title":"Arts & Culture","url":"/Arts-Culture"},"links":[{"title":"Entertainment & Pop Culture","url":"/browse/Entertainment-Pop-Culture"},{"title":"Literature","url":"/browse/Literature"},{"title":"Sports & Recreation","url":"/browse/Sports-Recreation"},{"title":"Visual Arts","url":"/browse/Visual-Arts"}]}]}
#
#
#
#
#
#
#
#
#
#
#
#
#           Explore
#
#
#
#
#         Search Britannica
#
#
#
#
#
#             Click here to search
#
#
#
#
#
#
#
#
#         Search Britannica
#
#
#
#
#
#             Click here to search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Login
#
#
#
#
#
#
#    Subscribe
#
#
#
#    Subscribe
#
#
#
#
#
#
#
#
#           Games & Quizzes
#           History & Society
#           Science & Tech
#           Biographies
#           Animals & Nature
#           Geography & Travel
#           Arts & Culture
#           Money
#           Videos
#           On This Day
#           One Good Fact
#           Dictionary
#           New Articles
#
#         History & Society
#
#             Lifestyles & Social Issues
#             Philosophy & Religion
#             Politics, Law & Government
#             World History
#
#         Science & Tech
#
#             Health & Medicine
#             Science
#             Technology
#
#         Biographies
#
#             Browse Biographies
#
#         Animals & Nature
#
#             Birds, Reptiles & Other Vertebrates
#             Bugs, Mollusks & Other Invertebrates
#             Environment
#             Fossils & Geologic Time
#             Mammals
#             Plants
#
#         Geography & Travel
#
#             Geography & Travel
#
#         Arts & Culture
#
#             Entertainment & Pop Culture
#             Literature
#             Sports & Recreation
#             Visual Arts
#
#
#           Companions
#           Demystified
#           Image Galleries
#           Infographics
#           Lists
#           Podcasts
#           Spotlights
#           Summaries
#           The Forum
#           Top Questions
#           #WTFact
#
#
#           100 Women
#           Britannica Kids
#           Saving Earth
#           Space Next 50
#           Student Center
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search Britannica
#
#
#
#
#
#             Click here to search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Games & Quizzes
# 				History & Society
# 				Science & Tech
# 				Biographies
# 				Animals & Nature
# 				Geography & Travel
# 				Arts & Culture
# 				Money
# 				Videos
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             November 6, 2023
#
#
#
#
#
#
#
#
#                   Native American Heritage Month
#
#
#                     November is National Native American Heritage Month, a celebration of indigenous cultures—and a chance to correct the narrative. Awareness of Native American history has grown since this heritage month was first observed in 1990. But when you think about how indigenous cultures were portrayed in history books and Hollywood, there was nowhere to go but up. This November, take a moment to reflect on how America’s “settlers” could also be called—as a matter of record—invaders.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/wiWAWhAx.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/05/212505-138-59E827CD/Shrinking-Native-American-lands-in-the-United-States-indigenous-peoples.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/49T2YeUk", "label": "English" } ]
#                                                 }
#
#
#
#
#
#
#
#
#
#
# 				How Native Americans Lost Their Land in the United States
#                                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/1qR63Xmk.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/27/233327-138-6322D271/Who-was-Tecumseh.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/L2kWb27a", "label": "English" } ]
#                                                 }
#
#
#
#
#
#
#
#
#
#
# 				Tecumseh’s Dream of a Native American Confederacy
#                                 Encyclopaedia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 {
#                                                 "sources": [ { "file" : "//content.jwplatform.com/manifests/hHFpxbXe.m3u8" } ],
#                                                 "image": "https://cdn.britannica.com/72/233772-138-7B1C1098/who-was-Sitting-Bull.jpg",
#                                                 "tracks": [ { "file" : "//assets-jpcust.jwpsrv.com/tracks/LkFcE7vn", "label": "English" } ]
#                                                 }
#
#
#
#
#
#
#
#
#
#
# 				How Sitting Bull United and Mobilized the Sioux Nation
#                                 Encyclopaedia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#                     Discover More
#
#
#
#
# 				The Six Nations of the Iroquois Confederacy
#
#
#
#
# 				Quiz: Which English Words Have Native American Origins?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                   The First Tip Off
#
#                             Unlike many other sports, basketball has one definite point of origin—and his name is James Naismith (pictured below), who was born on this day in 1861. Here’s more on basketball’s creator, and its evolution.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Game plan
#                                     The Canadian-born Naismith was a physical education teacher at a YMCA Training School in Springfield, Mass., when, in 1891, he was tasked with creating an indoor game—something more lively than the school’s callisthenics curriculum.
#
#
#
#
#
#
#
#
#
# 				Home court
#                                     Many of basketball’s fundamental rules can be traced to his first blueprint. Naismith hung the basket off of the gym’s only fixture, a railing 10 feet above the floor, which remains the regulation height. His original rules, such as prohibiting walking or running with the ball and limiting physical contact, are still the basis of the game.
#
#
#
#
#
#
#
#
#
# 				Overtime
#                                     Still, there was room for improvement. That first basket was a real basket, so whenever a shot was sunk, somebody had to climb a ladder to retrieve the ball. And each team originally had nine players, because Naismith’s phys-ed class had 18 students. Naismith, though, wasn’t done inventing—he is widely credited as creating the first protective helmet for football players.
#
#
#
#
#
#
#
#
#                     UPI/Bettmann Archive
#
#
#
#
#
#
#
#
#
# 				Popular on Britannica
#
#
#
#
#
#
# 								Articles
#
#
# 										Guy Fawkes Day
#
#
# 										Bermuda Triangle
#
#
# 										artificial intelligence
#
#
# 										Nepal earthquake of 2015
#
#
# 										Philippines
#
#
# 										earthquake
#
#
# 										list of state capitals in the United States
#
#
# 										Thanksgiving Day
#
#
# 										American Revolution
#
#
# 										anti-Semitism
#
#
#
#
# 										Show More
# 										Show Less
#
#
#
#
#
#
#
#
# 								Features
#
#
# 										Why Do We Celebrate Halloween?
#
#
# 										Why Is It Called Black Friday?
#
#
# 										How Mike the Chicken Survived Without a Head
#
#
# 										What Is Known (and Not Known) About the Bermuda Triangle
#
#
# 										Where Does the Concept of a “Grim Reaper” Come From?
#
#
# 										Pro and Con: School Uniforms
#
#
# 										How Many Electoral College Votes Does Each U.S. State Have?
#
#
# 										Feliz Día de los Muertos
#
#
# 										History of Technology Timeline
#
#
# 										26 Decade-Defining Events in U.S. History
#
#
#
#
# 										Show More
# 										Show Less
#
#
#
#
#
#
#
#
# 								Lists
#
#
# 										6 Animals We Ate Into Extinction
#
#
# 										7 of History's Most Notorious Serial Killers
#
#
# 										Timeline of the American Revolution
#
#
# 										6 Wars of Independence
#
#
# 										9 Noteworthy Bog Bodies (And What They Tell Us)
#
#
# 										Inventors and Inventions of the Industrial Revolution
#
#
# 										10 Famous Artworks by Leonardo da Vinci
#
#
# 										11 Egyptian Gods and Goddesses
#
#
# 										The 6 Deadliest Earthquakes Since 1950
#
#
# 										9 Things You Might Not Know About Adolf Hitler
#
#
#
#
# 										Show More
# 										Show Less
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 							Household Finance
#
#
# 							Investing
#
#
# 							Retirement
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Social Security COLA 2024: What you need to know
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		What is stagflation? A double whammy of headwinds
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Certificate of deposit (CD) vs. savings account: How to choose
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Will vs. living trust: What’s the difference?
#
#
#
#
#
#
#
#
#
#
#
# 						  New on Britannica
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												15 of the best birdsongs
#
# 												Check out this collection of birdsongs to help identify which bird is behind those chirps you hear so often.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												Human composting
#
# 												This new type of alternative burial rite turns human remains into soil or compost over a period of 60 to 90 days.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												How wireless earbuds work
#
# 												You use them all the time but have you ever stopped to think about the science behind how those wireless earbuds work?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 												Government shutdown
#
# 												As Congress heads toward a government shutdown, here’s a breakdown of how and why these things occur.
#
#
#
#
#
#
#
#
#
# 				Trending Quizzes
# 				See All Quizzes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Where in America is That?
#
#
# 						Crisscross the U.S. by placing these famous landmarks.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				From Athena to Zeus: Basics of Greek Mythology
#
#
# 						Do you know which hero took a dip in the River Styx? Or what mysteries lurk inside the Labyrinth?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Ultimate Animals Quiz
#
#
# 						What is a rattlesnake’s rattle made of? What animals can go over 180 miles an hour?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Guess the Language! Quiz
#
#
# 						Can you recognize a language by its greeting?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Best Picture Movie Quote Quiz
#
#
# 						Take this quiz or you may regret it. Maybe not today, maybe not tomorrow, but soon, and for the rest of your life.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				American Civil Rights Movement Quiz
#
#
# 						Test your knowledge of Americans’ tumultuous fight to end racial segregation and discrimination.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Name That Thing: Tools
#
#
# 						A handy quiz to test your tool acumen.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				The Dog Breed Quiz
#
#
# 						Find out which breed can outrun a cheetah, which breed was created by monks, and much more.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Baking and Baked Goods Quiz
#
#
# 						You may have a sweet tooth, but how much do you know about baking and baked goods? Test your knowledge with this quiz.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				First Ladies of the United States Quiz
#
#
# 						They have been hostesses, helpers, advisers, gatekeepers, guardians, confidantes, and sometimes formidable powers behind...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					 Featured Videos
# 					 See All Videos
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             A look behind the curtain in Edgar Degas's The Ballet Class
#
#
#
#             Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/82/248782-138-842428B7/The-Ballet-Class-Edgar-Degas.jpg","sources":[{"file":"//content.jwplatform.com/manifests/hToaxhsn.m3u8"}],"assetId":248782,"adfile":"//content.jwplatform.com/manifests/a0dMagtb.m3u8","title":"A look behind the curtain in Edgar Degas's <em>The Ballet Class<\/em>","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/3rADrCUY.vtt","label":"English"}],"transcriptUrl":"/video/248782/The-Ballet-Class-Edgar-Degas#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		A look behind the curtain in Edgar Degas's The Ballet Class
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/60/250260-138-09F49202/Paris-Street-Rainy-Day-Gustave-Caillebotte-1877.jpg","sources":[{"file":"//content.jwplatform.com/manifests/MZGUibb3.m3u8"}],"assetId":250260,"adfile":"//content.jwplatform.com/manifests/f21gLhye.m3u8","title":"<em>Paris Street; Rainy Day<\/em> and a vision of the modern city","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/Z7DTvFo5.vtt","label":"English"}],"transcriptUrl":"/video/250260/Paris-Street-Rainy-Day-Gustave-Caillebotte-1877#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Paris Street; Rainy Day and a vision of the modern city
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/48/249448-138-E091CC5D/Nocturne-in-Black-and-Gold-the-Falling-Rocket-James-McNeill-Whistler.jpg","sources":[{"file":"//content.jwplatform.com/manifests/FS4aAnsf.m3u8"}],"assetId":249448,"adfile":"//content.jwplatform.com/manifests/RBR8T6rY.m3u8","title":"Why was <em>Nocturne in Black and Gold, the Falling Rocket<\/em> controversial?","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/QgCXssEQ.vtt","label":"English"}],"transcriptUrl":"/video/249448/Nocturne-in-Black-and-Gold-the-Falling-Rocket-James-McNeill-Whistler#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Why was Nocturne in Black and Gold, the Falling Rocket controversial?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 {"image":"https://cdn.britannica.com/87/248787-138-B1190CE9/Beauty-Looking-Back-Hishikawa-Moronobu.jpg","sources":[{"file":"//content.jwplatform.com/manifests/Mbi1vLjY.m3u8"}],"assetId":248787,"adfile":"//content.jwplatform.com/manifests/k0COsWtO.m3u8","title":"How <em>Beauty Looking Back<\/em> reflects Japanese history","tracks":[{"file":"//assets-jpcust.jwpsrv.com/tracks/02hbRCkE.vtt","label":"English"}],"transcriptUrl":"/video/248787/Beauty-Looking-Back-Hishikawa-Moronobu#transcript"}
#                 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		How Beauty Looking Back reflects Japanese history
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				Explore Britannica
#
#
#
#
#
# 				History & Society
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		6 Wars of Independence
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		5 of the World’s Most Devastating Financial Crises
#
#
#
#
#
#
#
#
# 				Science & Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		The Major Mass Extinctions That Shaped Life on Earth
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Do Lie Detectors Actually Work?
#
#
#
#
#
#
#
#
# 				Biographies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Matthew Perry
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Marie Laveau
#
#
#
#
#
#
#
#
# 				Animals & Nature
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		7 Brilliant Ways Seeds and Fruits Are Dispersed
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		The Horseshoe Crab: a Key Player in Ecology and Medicine
#
#
#
#
#
#
#
#
# 				Geography & Travel
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Palestine
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		How Long Is the Amazon River?
#
#
#
#
#
#
#
#
# 				Arts & Culture
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		9 Muses Who Were Artists
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Street Photography: How a Single Camera Created a Genre
#
#
#
#
#
#
#
#
#
# 				More From Britannica
#
#
#
# 							ProCon.org
# 							Award-winning ProCon.org promotes critical thinking, education, and informed citizenship by presenting the pro and con arguments to controversial issues in a straightforward, nonpartisan, freely accessible way.
#
#
#
#
# 							Britannica Money
# 							Discover all you need to know about retirement, investing, and household finance, without the jargon or agenda. Get reliable guidance, insight, and easy-to-understand explanations, written, edited, and verified to Britannica’s exacting standards.
#
#
#
#
# 							Advocacy for Animals
#
# 								Presenting Advocacy for Animals, a blog focused primarily on animal rights, wildlife conservation, environmental health and safety, and the legal and cultural issues related to these topics.  This blog is a source of information and a call to action. It is meant to be a provocation and a stimulus to thought regarding humanity’s relationship with nonhuman animals.
#
#
#
#
#
# 							Alain Elkann Interviews
# 							Alain has been writing a weekly interview column for the Italian newspaper La Stampa since 1989. His interviews celebrate some of the best known and successful personalities of the present day.
#
#
#
#
#
#
#
#
#
#
#
#
#
#       History at your fingertips –
#       Sign up here to see what happened On This Day, every day in your inbox!
#
#
#
#
#
#
#
#
#                 Enter your email
#
#
#
#                 Subscribe
#
#
#
#             By signing up for this email, you are agreeing to news, offers, and information from Encyclopaedia Britannica.
#             Click here to view our Privacy Notice. Easy unsubscribe links are provided in every email.
#
#
#
#
#
#        Thank you for subscribing!
#        Be on the lookout for your Britannica newsletter to get trusted stories delivered right to your inbox.
#
#
#
#
#
#
#
#
#
#                     Our Sites
#
#
#
#                     Britannica Kids
#                     Merriam-Webster
# 	                School & Library
# 	                Britannica Books
#                     Escola
#                     Britannica English-Arabic
#                     Nglish Sp-En Translation
# 	                ProCon
# 	                Britannica Merch
#
#
#
#
#
#
#
#                     Mobile
#
#
#
#                     iPhone App
#                     iPad App
#
#
#
#
#
#
#
#                     International
#
#
#
#                     Australia
#                     Brazil
#                     China
#                     Japan
#                     Latin America
#                     United Kingdom
#
#
#
#
#
#
#
#                     Content & Editorial
#
#
#
# 	                Encyclopaedia Britannica's Syndication API
#                     International Publishing
#                     Site Map
#                     New Articles
#
#
#
#
#
#
#
#                     Stay Connected
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Facebook
#
#
#         Twitter
#
#
#         YouTube
#
#
#         Instagram
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 About Us & Legal Info
#                 Contact Us
#                 Privacy Policy
#                 Terms of Use
#                 Diversity
#
#
#             ©2023 Encyclopædia Britannica, Inc.
#
#
#
#
#
#
#
#
# var IzWidget = IzWidget || {};
# (function (d)
# { var scriptElement = d.createElement('script'); scriptElement.type = 'text/javascript'; scriptElement.async = true; scriptElement.src = "https://insitez.blob.core.windows.net/site/f780f33e-a610-4ac2-af81-3eb184037547.js"; var node = d.getElementById('_informizely_script_tag'); node.parentNode.insertBefore(scriptElement, node); }
# )(document);
#
#
#
#
#
#
#
#
#
#
#
# {"pageType":"Home","templateName":null,"pageNumber":1,"pagesTotal":1,"pageId":null,"pageLength":null,"initialLoad":true,"lastPageOfScroll":true}
#
#
#
#
#
#
#
#
#
#
#
# [{"id":1012,"name":"SUBSCRIPTION_LINK_DESKTOP","selector":"#fake"}]
#
#
#
#
#             {
#                 "@context": "https://schema.org",
#                 "@type": "WebSite",
#                 "url": "https://www.britannica.com",
#                 "potentialAction": {
#                     "@type": "SearchAction",
#                     "target": "https://www.britannica.com/search?query={search_term}",
#                     "query-input": "required name=search_term"
#                 }
#             }
#
#               (function() {
#                 $.ajax({
#                   dataType: 'script',
#                   cache: true,
#                   url: 'https://cdn.britannica.com/mendel-resources/3-105/dist/home-page.js?v=3.105.08'
#                 });
#               })();
#
#
#
#
#
#
#
#
#
#
# {"leg":"D","userType":"ANONYMOUS","pageType":"Home","pageSubtype":null,"articleTemplateType":null,"gisted":false}
#
#
#
#
#
#         function gaPageLoad(pathname, documentLocation) {
#             pathname = pathname || location.pathname;
#             documentLocation = documentLocation || document.querySelector('html').getAttribute('data-ytrk-page');
#
#             if (documentLocation) {
#                 documentLocation = documentLocation.replace(/ /g, '/');
#
#                 if (documentLocation.charAt(0) !== '/') {
#                     documentLocation = '/' + documentLocation;
#                 }
#
#                 window.dataLayer = window.dataLayer || [];
#
#                 function gtag() {
#                     dataLayer.push(arguments);
#                 }
#
#                 gtag('js', new Date());
#
#                 gtag('set', {
#                     'dimension1': 'ANONYMOUS',
#                     'dimension2': 'D',
#                     'dimension3': 'D'
#                 });
#
#                 //console.log( "*****[UA]***** -> ", documentLocation + pathname + decodeURI(location.search) );
#
#                 gtag('config', 'UA-6636134-11', {
#                     'page_path': documentLocation + pathname + decodeURI(location.search),
#                     'link_attribution': true,
#                 });
#             }
#         }
#
#         gaPageLoad();
#
#
#     EBStat={accountId:-1,hostnameOverride:'webstats.eb.com',domain:'www.britannica.com', json:''};
#
#
#
#             ( function() {
#                 $.ajax( { dataType: 'script', cache: true, url: '//www.britannica.com/webstats/mendelstats.js?v=1' } )
#                  .done( function() {
#                      try {writeStat(null,EBStat);}
#                      catch(err){}
#                  } );
#             })();

# %%
# Find all articles
summaries = soup.find_all("tr", class_="athing")
summaries[0]

# %%
# Extract title
summaries[0].find("a", class_="storylink").get_text().strip()

# %%
# Find all articles, extract titles
articles = []
summaries = soup.find_all("tr", class_="athing")
for summary in summaries:
    title = summary.find("a", class_="storylink").get_text().strip()
    articles.append((title))

print(len(articles), "Article summaries found. Sample:")
print(articles[0])

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower()
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text)
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
